# %% [markdown]
# The [Capability Maturity Model](https://en.wikipedia.org/wiki/Capability_Maturity_Model) was originally developed as a tool for objectively assessing the ability of government contractors' processes to implement a contracted software project. The CMM then grew into the [Capability Maturity Model Integration (CMMI)](https://en.wikipedia.org/wiki/Capability_Maturity_Model_Integration) which is a process level improvement training and appraisal program.
#
# Maturity Models go even deeper than that with the Government Accountability Office with ORGANIZATIONAL
# TRANSFORMATION: [A Framework for Assessing and Improving Enterprise Architecture Management (Version 2.0)](https://www.gao.gov/assets/80/77233.pdf) dated: August 2010
#
# and an associated document ORGANIZATIONAL TRANSFORMATION: [Enterprise Architecture Value Needs to Be Measured and Reported](https://www.gao.gov/assets/650/648827.pdf) dated: September 2012
#
# INFORMATION TECHNOLOGY: [Agencies Need to Develop Modernization Plans for Critical Legacy Systems](https://www.gao.gov/assets/700/699616.pdf)
#
# [General Services Administration’s Unified Shared Services Management’s 5 Modernization and Migration Management (M3) Playbook and M3 Playbook Guidance](https://ussm.gsa.gov/m3/)
#
# [M3 Playbook](https://ussm.gsa.gov/assets/files/2018_M3_Playbook_Final.pdf)

# %% [markdown]
# As congress turns up the heat on making government accountable, how do we benchmark and track progress of modernization efforts with respect to Artificial Intelligence (AI) initiatives?
#
# Why do I bring up AI?
#
# <img src="images/EO13859.png" align="center" alt="EO13859" width = "600">
#
# EO13859 is pursuing five pillars for advancing AI:
# 1. __Invest__ in AI research and development (R&D),
# 2. __Unleash__ AI resources,
# 3. __Remove__ barriers to AI innovation,
# 4. __Train__ an AI-ready workforce, and
# 5. __Promote__ an international environment that is supportive of American AI innovation and its responsible use.
#
# ___The U.S. is also actively leveraging AI to help the Federal government work smarter in its own services and missions in trustworthy ways.___

# %% [markdown]
# When I first arrived we conducted a little bake off on utilizing simple cloud based AI services for
# [Anil's Testimony](https://docs.google.com/presentation/d/1GBEssjy9Eis1dTAsf5PviQde3lxxYG9KT4Oi2S_ODTI/edit#slide=id.p1)
#
# Why are we discussing a model? Because COE will need a way to benchmark and track progress of how well the engagement is progressing with it's IT modernization but also keeping the pulse of the AI push. Let's take a look at this congressional oversight committee ["Making IT a Priority for The Federal Government"](https://drive.google.com/file/d/1llbwlT9CPJo_KrPSUd6Km3KVwcGsJu17/view?usp=sharing)
#
# <img src="images/Congressional_Heat.png" align="center" alt="Mark Meadows" width = "600">
#
#
# The initial thought process was to tie together this idea of setting a baseline and monitoring progress in terms of AI, so we came up with:
#
# ## AI Capability Maturity Model
# One of the largest challenges currently is a realization that organizations performing machine learning, is to have a repeatable and scalable (horizontally and vertically) Machine Learning foundation and process. Herein lies a model that in itself can be adapted and changed over time.
#
# - __Level 0__ - Secure Cloud infrastructure Ability to consistently scale and share AI services and resources horizontally and vertically
# - __Level 1__ - Data Pipeline created with a continuous delivery of data
# - __Level 2__ - Agile Software Development process formed
# - __Level 3__ - Operational requirements process formed
# - __Level 4__ - Ability to conduct Exploratory and Deep Data Analysis and share and catalog results
# - __Level 5__ - Has a Traditional ML Process with ability to measure, share and catalog results
# - __Level 6__ - Has a AutoML Process with ability to measure, share and catalog results
# - __Level 7__ - ML Operational Feedback Loop measures effectiveness
#
# We'll call this AI_CMM version 0.
#
# This idea of a feedback loop turned into the AI Sustainment Cycle shown below:
#
# <img src="images/AI_Sustainment_Cycle.png" align="center" alt="AI_CMM_v1" width = "500">
#
# Once this central idea was captured, we put the idea into the context of a two-dimensional model that CMU CMMI is based on and shown below:
#
# <img src="images/AI_CMM_v1.png" align="center" alt="AI_CMM_v1" width = "600">

# %% [markdown]
# Once we had this model which we'll call version 1, we started to level up the operational maturity, breaking out and adding layers. We now have a version 2 that has a little more meat to it and have 3 questions created for each block. This effort now include a wider array of the COE team to help building it out making it a team effort.
#
# <img src="images/20200921_AI_CMM_v2.png" align="center" alt="AI_CMM_v1" width = "600">

# %% [markdown]
# We have toyed around also with incorporating other layers to it such as T&EOps for those organizations such as DoD, DoE and NASA that incorporate a stringent Test and Evaluation effort.
#
# <img src="images/T&E.png" align="center" alt="AI_CMM_v1" width = "600">

# %% [markdown]
# Once we got here, we starting thinking through the questions we might ask to be able to create a scoring system. We ask 3 questions in each Operational/Organizational block to create sum score horizontally and vertically. We'll call this version 3.
#
# <img src="images/AI_CMM_v3.png" align="center" alt="AI_CMM_v1" width = "600">

# %% [markdown]
# We incorporated a designer on the team to work to make a more readable model fast consumable design where the team had input on.
#
# <img src="images/Design.png" align="center" alt="AI_CMM_v1" width = "600">

# %% [markdown]
# <img src="images/AI_CMM_v4.png" align="center" alt="AI_CMM_v4" width = "800">
#
# Here we present AI CMM v4

# %% [markdown]
# With our engagements I wanted something a little more concrete so I started mapping the AI CMM to the main cloud providers starting with the top and working my way down. Currently according to Gartner AWS, followed by Azure, followed by GCP.
#
# <img src="images/Gartner_cloud.png" align="center" alt="Gartner Cloud Leaders" width = "400">
#
# <img src="images/CloudAI.png" align="center" alt="Gartner Cloud AI Services" width = "400">
#
# <img src="images/AWS_AI_ML_Stack.png" align="center" alt="AWS_AI_CMM_MAP" width = "800">
#
# <img src="images/PeopleOps.png" align="center" alt="PeopleOps" width = "400">

# %% [markdown]
# That's a lot of services, did I get them all?
#
# - [AWS Services](https://docs.google.com/spreadsheets/d/1VgnePn1Im-NaGa3oPofcv7NZzHxz0ny3Q6rjGPh2-vA/edit#gid=1278028925)
# - [Azure Services](https://docs.google.com/spreadsheets/d/1wR9xMezJJmn2LBeMvlWN9uuSTBP0VnBmBmqH-o0_0n8/edit#gid=211060091)
# - [GCP Services](https://docs.google.com/spreadsheets/d/1EpfVAE1daEb_5u4enER9xTMyeYRyO0pKISrsmvEGrOk/edit#gid=442823116)

# %%
import pandas as pd
aws_df = pd.read_csv('data/AWS2.csv')
azure_df = pd.read_csv('data/Azure2.csv')
gcp_df = pd.read_csv('data/GCP.csv')

# %%
aws_df
# Out:
#                             Name  \
# 0             Alexa for Business
# 1             Amazon API Gateway
# 2             Amazon API Gateway
# 3                 Amazon AppFlow
# 4           Amazon AppStream 2.0
# ..                           ...
# 219  Reserved Instance Reporting
# 220                Savings Plans
# 221            TensorFlow on AWS
# 222             VM Import/Export
# 223          VMware Cloud on AWS
#
#                                            Description  \
# 0                 Empower your organization with Alexa
# 1                      Build, deploy, and manage API's
# 2                       Build, deploy, and manage APIs
# 3     No code integration for SaaS apps & AWS services
# 4    Stream desktop applications securely to a browser
# ..                                                 ...
# 219     Dive deeper into your reserved instances (RIs)
# 220  Save up to 72% on compute usage with flexible ...
# 221           Open-source machine intelligence library
# 222  import virtual machine images from your existi...
# 223       Build a hybrid cloud without custom hardware
#
#                         Type FedRAMP Moderate (East/West)  \
# 0      Business Applications                          NaN
# 1                     Mobile                            ✓
# 2                 Networking                            ✓
# 3    Application Integration                          NaN
# 4         End User Computing                            ✓
# ..                       ...                          ...
# 219          Cost Management                          NaN
# 220          Cost Management                          NaN
# 221         Machine Learning                          NaN
# 222                Migration                            ✓
# 223                  Compute                          NaN
#
#     FedRAMP High (GovCloud) DoD CC SRG IL2 (East/West)  \
# 0                       NaN                        NaN
# 1                         ✓                          ✓
# 2                         ✓                          ✓
# 3                       NaN                        NaN
# 4                         ✓                          ✓
# ..                      ...                        ...
# 219                     NaN                        NaN
# 220                     NaN                        NaN
# 221                     NaN                        NaN
# 222                       ✓                          ✓
# 223                     NaN                        NaN
#
#     DoD CC SRG IL2 (GovCloud) DoD CC SRG IL4 (GovCloud)  \
# 0                         NaN                       NaN
# 1                           ✓                         ✓
# 2                           ✓                         ✓
# 3                         NaN                       NaN
# 4                           ✓                         ✓
# ..                        ...                       ...
# 219                       NaN                       NaN
# 220                       NaN                       NaN
# 221                       NaN                       NaN
# 222                         ✓                         ✓
# 223                       NaN                       NaN
#
#     DoD CC SRG IL5 (GovCloud) DoD CC SRG IL6 (AWS Secret Region)
# 0                         NaN                                NaN
# 1                           ✓                                NaN
# 2                           ✓                                NaN
# 3                         NaN                                NaN
# 4                           ✓                                NaN
# ..                        ...                                ...
# 219                       NaN                                NaN
# 220                       NaN                                NaN
# 221                       NaN                                NaN
# 222                         ✓                        DISA Review
# 223                       NaN                                NaN
#
# [224 rows x 10 columns]

# %%
azure_df
# Out:
#                              Name  \
# 0        Anomaly Detector PREVIEW
# 1                        API Apps
# 2                        API Apps
# 3                        API Apps
# 4                  API Management
# ..                            ...
# 332                      Web Apps
# 333  Windows 10 IoT Core Services
# 334       Windows Virtual Desktop
# 335       Windows Virtual Desktop
# 336                       Xamarin
#
#                                            Description  \
# 0    Easily add anomaly detection capabilities to y...
# 1                  Easily build and consume Cloud APIs
# 2                  Easily build and consume Cloud APIs
# 3                  Easily build and consume Cloud APIs
# 4    Publish APIs to developers, partners, and empl...
# ..                                                 ...
# 332  Quickly create and deploy mission critical web...
# 333  Long-term OS support and services to manage de...
# 334  The best virtual desktop experience, delivered...
# 335  The best virtual desktop experience, delivered...
# 336            Create cloud-powered mobile apps faster
#
#                         Type FedRAMP Moderate FedRAMP High Planned 2020  \
# 0           Machine Learning              NaN          NaN          NaN
# 1                    Compute              NaN          NaN          NaN
# 2                 Containers              NaN          NaN          NaN
# 3                        Web              NaN          NaN          NaN
# 4                Integration               ✔️           ✔️          NaN
# ..                       ...              ...          ...          ...
# 332                      Web               ✔️           ✔️          NaN
# 333                      IoT              NaN          NaN          NaN
# 334                  Compute               ✔️           ✔️          NaN
# 335  Windows Virtual Desktop               ✔️           ✔️          NaN
# 336                   Mobile              NaN          NaN          NaN
#
#     DISA IL 2 DISA IL 4 DISA IL 5 ** DISA IL 6
# 0         NaN       NaN          NaN       NaN
# 1         NaN       NaN          NaN       NaN
# 2         NaN       NaN          NaN       NaN
# 3         NaN       NaN          NaN       NaN
# 4          ✔️        ✔️           ✔️       NaN
# ..        ...       ...          ...       ...
# 332        ✔️        ✔️           ✔️        ✔️
# 333       NaN       NaN          NaN       NaN
# 334       NaN       NaN          NaN       NaN
# 335       NaN       NaN          NaN       NaN
# 336       NaN       NaN          NaN       NaN
#
# [337 rows x 10 columns]

# %%
gcp_df
# Out:
#                            Name  \
# 0                      BigQuery
# 1                Cloud Composer
# 2             Cloud Data Fusion
# 3    Cloud Life Sciences (beta)
# 4                  Data Catalog
# ..                          ...
# 169        Google Maps Platform
# 170                        Meet
# 171         Phishing Protection
# 172        reCAPTCHA Enterprise
# 173                    Web Risk
#
#                                            Description  \
# 0    Data warehouse for business agility and insights.
# 1    Workflow orchestration service built on Apache...
# 2    Data integration for building and managing dat...
# 3    Tools for managing, processing, and transformi...
# 4    Metadata solution for exploring and managing d...
# ..                                                 ...
# 169  Create immersive location experiences and impr...
# 170                       Easy-to-join video meetings.
# 171            Protect your users from phishing sites.
# 172  Help protect your website from fraudulent acti...
# 173  Detect malicious URLs on your website and in c...
#
#                          Type
# 0                   Analytics
# 1                   Analytics
# 2                   Analytics
# 3                   Analytics
# 4                   Analytics
# ..                        ...
# 169                 User Apps
# 170                 User Apps
# 171  User Protection Services
# 172  User Protection Services
# 173  User Protection Services
#
# [174 rows x 3 columns]

# %%
print("AWS has: ", aws_df['Name'].nunique(),"unique services")
# Out:
# AWS has:  213 unique services

# %%
print("Azure has: ", azure_df['Name'].nunique(),"unique services")
# Out:
# Azure has:  256 unique services

# %%
print("GCP has: ", gcp_df['Name'].nunique(),"unique services")
# Out:
# GCP has:  158 unique services

# %%
aws_type = aws_df.groupby(['Type']).count()
aws_type
# Out:
#                                  Name  Description  \
# Type
# AR & VR                             1            1
# Analytics                          14           14
# Application Integration             7            7
# Blockchain                          2            2
# Business Applications               5            5
# Compute                            13           13
# Containers                          5            5
# Cost Management                     5            5
# Customer Engagement                 4            4
# Databases                          19           19
# Developer Tools                    15           15
# End User Computing                  4            4
# Game Tech                           2            2
# IoT                                12           12
# Machine Learning                   25           25
# Management & Governance            22           22
# Media                              10           10
# Migration                          11           11
# Mobile                              5            5
# Networking                         12           12
# Quantum                             1            1
# Robotics                            1            1
# Satellite                           1            1
# Security, Identity & Compliance    18           18
# Storage                            10           10
#
#                                  FedRAMP Moderate (East/West)  \
# Type
# AR & VR                                                     0
# Analytics                                                   8
# Application Integration                                     4
# Blockchain                                                  0
# Business Applications                                       2
# Compute                                                     9
# Containers                                                  4
# Cost Management                                             0
# Customer Engagement                                         3
# Databases                                                  11
# Developer Tools                                             4
# End User Computing                                          3
# Game Tech                                                   0
# IoT                                                         3
# Machine Learning                                            7
# Management & Governance                                    13
# Media                                                       1
# Migration                                                   5
# Mobile                                                      2
# Networking                                                  8
# Quantum                                                     0
# Robotics                                                    0
# Satellite                                                   0
# Security, Identity & Compliance                            11
# Storage                                                     4
#
#                                  FedRAMP High (GovCloud)  \
# Type
# AR & VR                                                0
# Analytics                                              7
# Application Integration                                3
# Blockchain                                             0
# Business Applications                                  0
# Compute                                                9
# Containers                                             4
# Cost Management                                        0
# Customer Engagement                                    1
# Databases                                             11
# Developer Tools                                        4
# End User Computing                                     3
# Game Tech                                              0
# IoT                                                    3
# Machine Learning                                       7
# Management & Governance                               11
# Media                                                  1
# Migration                                              5
# Mobile                                                 2
# Networking                                             6
# Quantum                                                0
# Robotics                                               0
# Satellite                                              0
# Security, Identity & Compliance                        8
# Storage                                                5
#
#                                  DoD CC SRG IL2 (East/West)  \
# Type
# AR & VR                                                   0
# Analytics                                                 8
# Application Integration                                   4
# Blockchain                                                0
# Business Applications                                     2
# Compute                                                   9
# Containers                                                4
# Cost Management                                           1
# Customer Engagement                                       3
# Databases                                                10
# Developer Tools                                           4
# End User Computing                                        3
# Game Tech                                                 0
# IoT                                                       3
# Machine Learning                                          6
# Management & Governance                                  13
# Media                                                     1
# Migration                                                 5
# Mobile                                                    2
# Networking                                                8
# Quantum                                                   1
# Robotics                                                  0
# Satellite                                                 0
# Security, Identity & Compliance                          12
# Storage                                                   5
#
#                                  DoD CC SRG IL2 (GovCloud)  \
# Type
# AR & VR                                                  0
# Analytics                                                7
# Application Integration                                  3
# Blockchain                                               0
# Business Applications                                    0
# Compute                                                  9
# Containers                                               4
# Cost Management                                          0
# Customer Engagement                                      1
# Databases                                               10
# Developer Tools                                          4
# End User Computing                                       3
# Game Tech                                                0
# IoT                                                      3
# Machine Learning                                         6
# Management & Governance                                 11
# Media                                                    1
# Migration                                                5
# Mobile                                                   2
# Networking                                               7
# Quantum                                                  1
# Robotics                                                 0
# Satellite                                                0
# Security, Identity & Compliance                          9
# Storage                                                  5
#
#                                  DoD CC SRG IL4 (GovCloud)  \
# Type
# AR & VR                                                  0
# Analytics                                                7
# Application Integration                                  3
# Blockchain                                               0
# Business Applications                                    0
# Compute                                                  9
# Containers                                               4
# Cost Management                                          0
# Customer Engagement                                      1
# Databases                                                9
# Developer Tools                                          4
# End User Computing                                       3
# Game Tech                                                0
# IoT                                                      3
# Machine Learning                                         6
# Management & Governance                                 11
# Media                                                    1
# Migration                                                5
# Mobile                                                   2
# Networking                                               7
# Quantum                                                  1
# Robotics                                                 0
# Satellite                                                0
# Security, Identity & Compliance                          9
# Storage                                                  5
#
#                                  DoD CC SRG IL5 (GovCloud)  \
# Type
# AR & VR                                                  0
# Analytics                                                7
# Application Integration                                  3
# Blockchain                                               0
# Business Applications                                    0
# Compute                                                  9
# Containers                                               4
# Cost Management                                          0
# Customer Engagement                                      1
# Databases                                               10
# Developer Tools                                          4
# End User Computing                                       3
# Game Tech                                                0
# IoT                                                      3
# Machine Learning                                         6
# Management & Governance                                 11
# Media                                                    1
# Migration                                                5
# Mobile                                                   2
# Networking                                               7
# Quantum                                                  1
# Robotics                                                 0
# Satellite                                                0
# Security, Identity & Compliance                          9
# Storage                                                  5
#
#                                  DoD CC SRG IL6 (AWS Secret Region)
# Type
# AR & VR                                                           0
# Analytics                                                         3
# Application Integration                                           3
# Blockchain                                                        0
# Business Applications                                             0
# Compute                                                           5
# Containers                                                        0
# Cost Management                                                   0
# Customer Engagement                                               0
# Databases                                                         8
# Developer Tools                                                   2
# End User Computing                                                0
# Game Tech                                                         0
# IoT                                                               0
# Machine Learning                                                  0
# Management & Governance                                           9
# Media                                                             0
# Migration                                                         2
# Mobile                                                            0
# Networking                                                        5
# Quantum                                                           0
# Robotics                                                          0
# Satellite                                                         0
# Security, Identity & Compliance                                   2
# Storage                                                           3

# %%
aws_IL6 = aws_df['DoD CC SRG IL6 (AWS Secret Region)']
aws_IL6.count()
# Out:
# 42

# %%
azure_IL6 = azure_df['DISA IL 6']
azure_IL6.count()
# Out:
# 50

# %%
aws_IL5 = aws_df['DoD CC SRG IL5 (GovCloud)']
aws_IL5.count()
# Out:
# 91

# %%
azure_IL6 = azure_df['DISA IL 5 **']
azure_IL6.count()
# Out:
# 69

# %%
azure_type = azure_df.groupby(['Type']).count()
azure_type
# Out:
#                          Name  Description  FedRAMP Moderate  FedRAMP High  \
# Type
# Analytics                  20           20                12            12
# Blockchain                  5            5                 2             2
# Compute                    21           21                 9             9
# Containers                 10           10                 6             6
# Customer Service           11           11                 5             5
# Databases                  14           14                 9             9
# DevOps                      9            9                 1             1
# Developer Tools            16           16                 7             7
# Hybrid                     13           13                 5             5
# Identity                    8            8                 6             6
# Integration                 6            6                 4             4
# IoT                        21           21                 8             8
# Machine Learning           51           51                17            17
# Management & Governance    23           23                20            20
# Media                       8            8                 2             2
# Migration                   7            7                 6             6
# Mixed Reality               4            4                 0             0
# Mobile                      9            9                 4             4
# Networking                 21           21                18            18
# Security                   23           23                19            19
# Storage                    23           23                13            13
# Web                        13           13                 7             7
# Windows Virtual Desktop     1            1                 1             1
#
#                          Planned 2020  DISA IL 2  DISA IL 4  DISA IL 5 **  \
# Type
# Analytics                           2         13         11             6
# Blockchain                          0          2          2             1
# Compute                             0          7          7             6
# Containers                          0          5          4             2
# Customer Service                    0          8          2             0
# Databases                           0          8          8             6
# DevOps                              1          2          2             1
# Developer Tools                     2          6          6             4
# Hybrid                              0          4          1             1
# Identity                            0          4          4             2
# Integration                         0          4          4             2
# IoT                                 1          7          5             1
# Machine Learning                    4         15         10             0
# Management & Governance             0         19         19             8
# Media                               0          2          1             1
# Migration                           0          5          5             2
# Mixed Reality                       0          0          0             0
# Mobile                              0          4          4             1
# Networking                          0         15         11            11
# Security                            0         19         15             5
# Storage                             1         12         10             7
# Web                                 0          7          5             2
# Windows Virtual Desktop             0          0          0             0
#
#                          DISA IL 6
# Type
# Analytics                        2
# Blockchain                       2
# Compute                          6
# Containers                       2
# Customer Service                 0
# Databases                        3
# DevOps                           0
# Developer Tools                  2
# Hybrid                           1
# Identity                         2
# Integration                      2
# IoT                              1
# Machine Learning                 0
# Management & Governance          6
# Media                            0
# Migration                        0
# Mixed Reality                    0
# Mobile                           0
# Networking                       8
# Security                         5
# Storage                          7
# Web                              1
# Windows Virtual Desktop          0

# %%
gcp_type = gcp_df.groupby(['Type']).count()
gcp_type
# Out:
#                             Name  Description
# Type
# API Management                12           12
# Analytics                     12           12
# Compute                       12           12
# Containers                     9            9
# Databases                      6            6
# Developer Tools               15           15
# Game Tech                      1            1
# Healthcare & Life Sciences     3            3
# Hybrid & Multi-cloud           4            4
# Identity & Access             10           10
# IoT                            2            2
# Machine Learning              20           20
# Management & Governance        8            8
# Media                          2            2
# Migration                      8            8
# Networking                    12           12
# Operations                     6            6
# Security & Identity           13           13
# Serverless Computing           4            4
# Storage                        8            8
# User Apps                      4            4
# User Protection Services       3            3

# %%
print("AWS has: ", aws_df['Type'].nunique(),"unique types of services")
# Out:
# AWS has:  25 unique types of services

# %%
print("Azure has: ", azure_df['Type'].nunique(),"unique types of services")
# Out:
# Azure has:  23 unique types of services

# %%
print("GCP has: ", gcp_df['Type'].nunique(),"unique types of services")
# Out:
# GCP has:  22 unique types of services

# %%
def dataframe_difference(df1, df2, which=None):
    """Find rows which are different between two DataFrames."""
    comparison_df = df1.merge(df2,
                              indicator=True,
                              how='outer')
    if which is None:
        diff_df = comparison_df[comparison_df['_merge'] != 'both']
    else:
        diff_df = comparison_df[comparison_df['_merge'] == which]
    diff_df.to_csv('data/diff.csv')
    return diff_df

# %%
#dataframe_difference(aws_df.groupby(['Type']), azure_df.groupby(['Type']))
aws_type
# Out:
#                                  Name  Description  \
# Type
# AR & VR                             1            1
# Analytics                          14           14
# Application Integration             7            7
# Blockchain                          2            2
# Business Applications               5            5
# Compute                            13           13
# Containers                          5            5
# Cost Management                     5            5
# Customer Engagement                 4            4
# Databases                          19           19
# Developer Tools                    15           15
# End User Computing                  4            4
# Game Tech                           2            2
# IoT                                12           12
# Machine Learning                   25           25
# Management & Governance            22           22
# Media                              10           10
# Migration                          11           11
# Mobile                              5            5
# Networking                         12           12
# Quantum                             1            1
# Robotics                            1            1
# Satellite                           1            1
# Security, Identity & Compliance    18           18
# Storage                            10           10
#
#                                  FedRAMP Moderate (East/West)  \
# Type
# AR & VR                                                     0
# Analytics                                                   8
# Application Integration                                     4
# Blockchain                                                  0
# Business Applications                                       2
# Compute                                                     9
# Containers                                                  4
# Cost Management                                             0
# Customer Engagement                                         3
# Databases                                                  11
# Developer Tools                                             4
# End User Computing                                          3
# Game Tech                                                   0
# IoT                                                         3
# Machine Learning                                            7
# Management & Governance                                    13
# Media                                                       1
# Migration                                                   5
# Mobile                                                      2
# Networking                                                  8
# Quantum                                                     0
# Robotics                                                    0
# Satellite                                                   0
# Security, Identity & Compliance                            11
# Storage                                                     4
#
#                                  FedRAMP High (GovCloud)  \
# Type
# AR & VR                                                0
# Analytics                                              7
# Application Integration                                3
# Blockchain                                             0
# Business Applications                                  0
# Compute                                                9
# Containers                                             4
# Cost Management                                        0
# Customer Engagement                                    1
# Databases                                             11
# Developer Tools                                        4
# End User Computing                                     3
# Game Tech                                              0
# IoT                                                    3
# Machine Learning                                       7
# Management & Governance                               11
# Media                                                  1
# Migration                                              5
# Mobile                                                 2
# Networking                                             6
# Quantum                                                0
# Robotics                                               0
# Satellite                                              0
# Security, Identity & Compliance                        8
# Storage                                                5
#
#                                  DoD CC SRG IL2 (East/West)  \
# Type
# AR & VR                                                   0
# Analytics                                                 8
# Application Integration                                   4
# Blockchain                                                0
# Business Applications                                     2
# Compute                                                   9
# Containers                                                4
# Cost Management                                           1
# Customer Engagement                                       3
# Databases                                                10
# Developer Tools                                           4
# End User Computing                                        3
# Game Tech                                                 0
# IoT                                                       3
# Machine Learning                                          6
# Management & Governance                                  13
# Media                                                     1
# Migration                                                 5
# Mobile                                                    2
# Networking                                                8
# Quantum                                                   1
# Robotics                                                  0
# Satellite                                                 0
# Security, Identity & Compliance                          12
# Storage                                                   5
#
#                                  DoD CC SRG IL2 (GovCloud)  \
# Type
# AR & VR                                                  0
# Analytics                                                7
# Application Integration                                  3
# Blockchain                                               0
# Business Applications                                    0
# Compute                                                  9
# Containers                                               4
# Cost Management                                          0
# Customer Engagement                                      1
# Databases                                               10
# Developer Tools                                          4
# End User Computing                                       3
# Game Tech                                                0
# IoT                                                      3
# Machine Learning                                         6
# Management & Governance                                 11
# Media                                                    1
# Migration                                                5
# Mobile                                                   2
# Networking                                               7
# Quantum                                                  1
# Robotics                                                 0
# Satellite                                                0
# Security, Identity & Compliance                          9
# Storage                                                  5
#
#                                  DoD CC SRG IL4 (GovCloud)  \
# Type
# AR & VR                                                  0
# Analytics                                                7
# Application Integration                                  3
# Blockchain                                               0
# Business Applications                                    0
# Compute                                                  9
# Containers                                               4
# Cost Management                                          0
# Customer Engagement                                      1
# Databases                                                9
# Developer Tools                                          4
# End User Computing                                       3
# Game Tech                                                0
# IoT                                                      3
# Machine Learning                                         6
# Management & Governance                                 11
# Media                                                    1
# Migration                                                5
# Mobile                                                   2
# Networking                                               7
# Quantum                                                  1
# Robotics                                                 0
# Satellite                                                0
# Security, Identity & Compliance                          9
# Storage                                                  5
#
#                                  DoD CC SRG IL5 (GovCloud)  \
# Type
# AR & VR                                                  0
# Analytics                                                7
# Application Integration                                  3
# Blockchain                                               0
# Business Applications                                    0
# Compute                                                  9
# Containers                                               4
# Cost Management                                          0
# Customer Engagement                                      1
# Databases                                               10
# Developer Tools                                          4
# End User Computing                                       3
# Game Tech                                                0
# IoT                                                      3
# Machine Learning                                         6
# Management & Governance                                 11
# Media                                                    1
# Migration                                                5
# Mobile                                                   2
# Networking                                               7
# Quantum                                                  1
# Robotics                                                 0
# Satellite                                                0
# Security, Identity & Compliance                          9
# Storage                                                  5
#
#                                  DoD CC SRG IL6 (AWS Secret Region)
# Type
# AR & VR                                                           0
# Analytics                                                         3
# Application Integration                                           3
# Blockchain                                                        0
# Business Applications                                             0
# Compute                                                           5
# Containers                                                        0
# Cost Management                                                   0
# Customer Engagement                                               0
# Databases                                                         8
# Developer Tools                                                   2
# End User Computing                                                0
# Game Tech                                                         0
# IoT                                                               0
# Machine Learning                                                  0
# Management & Governance                                           9
# Media                                                             0
# Migration                                                         2
# Mobile                                                            0
# Networking                                                        5
# Quantum                                                           0
# Robotics                                                          0
# Satellite                                                         0
# Security, Identity & Compliance                                   2
# Storage                                                           3

# %%
aws_df.groupby(['Type']).count()
# Out:
#                                  Name  Description  \
# Type
# AR & VR                             1            1
# Analytics                          14           14
# Application Integration             7            7
# Blockchain                          2            2
# Business Applications               5            5
# Compute                            13           13
# Containers                          5            5
# Cost Management                     5            5
# Customer Engagement                 4            4
# Databases                          19           19
# Developer Tools                    15           15
# End User Computing                  4            4
# Game Tech                           2            2
# IoT                                12           12
# Machine Learning                   25           25
# Management & Governance            22           22
# Media                              10           10
# Migration                          11           11
# Mobile                              5            5
# Networking                         12           12
# Quantum                             1            1
# Robotics                            1            1
# Satellite                           1            1
# Security, Identity & Compliance    18           18
# Storage                            10           10
#
#                                  FedRAMP Moderate (East/West)  \
# Type
# AR & VR                                                     0
# Analytics                                                   8
# Application Integration                                     4
# Blockchain                                                  0
# Business Applications                                       2
# Compute                                                     9
# Containers                                                  4
# Cost Management                                             0
# Customer Engagement                                         3
# Databases                                                  11
# Developer Tools                                             4
# End User Computing                                          3
# Game Tech                                                   0
# IoT                                                         3
# Machine Learning                                            7
# Management & Governance                                    13
# Media                                                       1
# Migration                                                   5
# Mobile                                                      2
# Networking                                                  8
# Quantum                                                     0
# Robotics                                                    0
# Satellite                                                   0
# Security, Identity & Compliance                            11
# Storage                                                     4
#
#                                  FedRAMP High (GovCloud)  \
# Type
# AR & VR                                                0
# Analytics                                              7
# Application Integration                                3
# Blockchain                                             0
# Business Applications                                  0
# Compute                                                9
# Containers                                             4
# Cost Management                                        0
# Customer Engagement                                    1
# Databases                                             11
# Developer Tools                                        4
# End User Computing                                     3
# Game Tech                                              0
# IoT                                                    3
# Machine Learning                                       7
# Management & Governance                               11
# Media                                                  1
# Migration                                              5
# Mobile                                                 2
# Networking                                             6
# Quantum                                                0
# Robotics                                               0
# Satellite                                              0
# Security, Identity & Compliance                        8
# Storage                                                5
#
#                                  DoD CC SRG IL2 (East/West)  \
# Type
# AR & VR                                                   0
# Analytics                                                 8
# Application Integration                                   4
# Blockchain                                                0
# Business Applications                                     2
# Compute                                                   9
# Containers                                                4
# Cost Management                                           1
# Customer Engagement                                       3
# Databases                                                10
# Developer Tools                                           4
# End User Computing                                        3
# Game Tech                                                 0
# IoT                                                       3
# Machine Learning                                          6
# Management & Governance                                  13
# Media                                                     1
# Migration                                                 5
# Mobile                                                    2
# Networking                                                8
# Quantum                                                   1
# Robotics                                                  0
# Satellite                                                 0
# Security, Identity & Compliance                          12
# Storage                                                   5
#
#                                  DoD CC SRG IL2 (GovCloud)  \
# Type
# AR & VR                                                  0
# Analytics                                                7
# Application Integration                                  3
# Blockchain                                               0
# Business Applications                                    0
# Compute                                                  9
# Containers                                               4
# Cost Management                                          0
# Customer Engagement                                      1
# Databases                                               10
# Developer Tools                                          4
# End User Computing                                       3
# Game Tech                                                0
# IoT                                                      3
# Machine Learning                                         6
# Management & Governance                                 11
# Media                                                    1
# Migration                                                5
# Mobile                                                   2
# Networking                                               7
# Quantum                                                  1
# Robotics                                                 0
# Satellite                                                0
# Security, Identity & Compliance                          9
# Storage                                                  5
#
#                                  DoD CC SRG IL4 (GovCloud)  \
# Type
# AR & VR                                                  0
# Analytics                                                7
# Application Integration                                  3
# Blockchain                                               0
# Business Applications                                    0
# Compute                                                  9
# Containers                                               4
# Cost Management                                          0
# Customer Engagement                                      1
# Databases                                                9
# Developer Tools                                          4
# End User Computing                                       3
# Game Tech                                                0
# IoT                                                      3
# Machine Learning                                         6
# Management & Governance                                 11
# Media                                                    1
# Migration                                                5
# Mobile                                                   2
# Networking                                               7
# Quantum                                                  1
# Robotics                                                 0
# Satellite                                                0
# Security, Identity & Compliance                          9
# Storage                                                  5
#
#                                  DoD CC SRG IL5 (GovCloud)  \
# Type
# AR & VR                                                  0
# Analytics                                                7
# Application Integration                                  3
# Blockchain                                               0
# Business Applications                                    0
# Compute                                                  9
# Containers                                               4
# Cost Management                                          0
# Customer Engagement                                      1
# Databases                                               10
# Developer Tools                                          4
# End User Computing                                       3
# Game Tech                                                0
# IoT                                                      3
# Machine Learning                                         6
# Management & Governance                                 11
# Media                                                    1
# Migration                                                5
# Mobile                                                   2
# Networking                                               7
# Quantum                                                  1
# Robotics                                                 0
# Satellite                                                0
# Security, Identity & Compliance                          9
# Storage                                                  5
#
#                                  DoD CC SRG IL6 (AWS Secret Region)
# Type
# AR & VR                                                           0
# Analytics                                                         3
# Application Integration                                           3
# Blockchain                                                        0
# Business Applications                                             0
# Compute                                                           5
# Containers                                                        0
# Cost Management                                                   0
# Customer Engagement                                               0
# Databases                                                         8
# Developer Tools                                                   2
# End User Computing                                                0
# Game Tech                                                         0
# IoT                                                               0
# Machine Learning                                                  0
# Management & Governance                                           9
# Media                                                             0
# Migration                                                         2
# Mobile                                                            0
# Networking                                                        5
# Quantum                                                           0
# Robotics                                                          0
# Satellite                                                         0
# Security, Identity & Compliance                                   2
# Storage                                                           3

# %%
fedramp_df = pd.read_csv('data/fedramp-2020-11-23.csv')

# %%
fedramp_df
# Out:
#       Cloud Service Provider  \
# 0                        18F
# 1                        18F
# 2                        18F
# 3                        18F
# 4                        18F
# ...                      ...
# 1164                 Zscaler
# 1165                 Zscaler
# 1166                 Zscaler
# 1167                 Zscaler
# 1168                 Zscaler
#
#                                  Cloud Service Offering    Type  \
# 0                                         18F Cloud.gov     JAB
# 1                                         18F Cloud.gov     JAB
# 2                                         18F Cloud.gov     JAB
# 3                                         18F Cloud.gov     JAB
# 4                                         18F Cloud.gov     JAB
# ...                                                 ...     ...
# 1164  Zscaler Internet Access – Government (Secure W...  Agency
# 1165  Zscaler Internet Access – Government (Secure W...  Agency
# 1166  Zscaler Private Access – Government (Zero Trus...     JAB
# 1167  Zscaler Private Access – Government (Zero Trus...     JAB
# 1168  Zscaler Private Access – Government (Zero Trus...     JAB
#
#       Leveraged A T O  Authorization Date  \
# 0                  No          01/18/2017
# 1                 Yes                 NaN
# 2                 Yes                 NaN
# 3                 Yes                 NaN
# 4                 Yes                 NaN
# ...               ...                 ...
# 1164              Yes                 NaN
# 1165               No                 NaN
# 1166               No          04/21/2020
# 1167              Yes                 NaN
# 1168              Yes                 NaN
#
#                                      Agency  \
# 0                         JAB Authorization
# 1           General Services Administration
# 2     Federal Deposit Insurance Corporation
# 3                     Department of Defense
# 4                Department of the Treasury
# ...                                     ...
# 1164                    Department of State
# 1165                  Department of Defense
# 1166                      JAB Authorization
# 1167      Federal Communications Commission
# 1168                    Department of State
#
#                                   Subagency      Independent Assessor
# 0                                       NaN    Coalfire Systems, Inc.
# 1                                       NaN                       NaN
# 2                                       NaN                       NaN
# 3        Defense Information Systems Agency                       NaN
# 4                  Internal Revenue Service                       NaN
# ...                                     ...                       ...
# 1164  State Office of the Inspector General                       NaN
# 1165                                    NaN  Schellman & Company, LLC
# 1166                                    NaN  Schellman & Company, LLC
# 1167                                    NaN                       NaN
# 1168  State Office of the Inspector General                       NaN
#
# [1169 rows x 8 columns]

# %%
fedramp_df.describe()
# Out:
#         Cloud Service Provider                         Cloud Service Offering  \
# count                     1169                                           1169
# unique                     237                                            293
# top                  Microsoft  Office 365 Multi-Tenant & Supporting Services
# freq                       118                                             57
#
#           Type  Leveraged A T O  Authorization Date  \
# count     1143             1169                 206
# unique       2                2                 171
# top     Agency              Yes          10/01/2020
# freq       691              876                   3
#
#                                          Agency  \
# count                                      1143
# unique                                       77
# top     Department of Health and Human Services
# freq                                         94
#
#                                  Subagency    Independent Assessor
# count                                  368                     290
# unique                                  84                      28
# top     Defense Information Systems Agency  Coalfire Systems, Inc.
# freq                                    22                     104

# %%
fedramp_df.head()
# Out:
#    Cloud Service Provider  Cloud Service Offering  Type  Leveraged A T O  \
# 0                     18F           18F Cloud.gov   JAB               No
# 1                     18F           18F Cloud.gov   JAB              Yes
# 2                     18F           18F Cloud.gov   JAB              Yes
# 3                     18F           18F Cloud.gov   JAB              Yes
# 4                     18F           18F Cloud.gov   JAB              Yes
#
#    Authorization Date                                 Agency  \
# 0          01/18/2017                      JAB Authorization
# 1                 NaN        General Services Administration
# 2                 NaN  Federal Deposit Insurance Corporation
# 3                 NaN                  Department of Defense
# 4                 NaN             Department of the Treasury
#
#                             Subagency    Independent Assessor
# 0                                 NaN  Coalfire Systems, Inc.
# 1                                 NaN                     NaN
# 2                                 NaN                     NaN
# 3  Defense Information Systems Agency                     NaN
# 4            Internal Revenue Service                     NaN

# %%
list(fedramp_df.columns)
# Out:
# [' Cloud Service Provider',
#  ' Cloud Service Offering',
#  ' Type',
#  ' Leveraged A T O',
#  ' Authorization Date',
#  ' Agency',
#  ' Subagency',
#  ' Independent Assessor']

# %%
fedramp_df.groupby([' Cloud Service Provider']).count()
# Out:
#                           Cloud Service Offering   Type   Leveraged A T O  \
#  Cloud Service Provider
# 18F                                            8      8                 8
# 1901 Group                                     2      2                 2
# AINS                                          16     16                16
# AT&T Cybersecurity                             1      1                 1
# Accellion USA, LLC.                            6      6                 6
# ...                                          ...    ...               ...
# Zscaler                                        7      7                 7
# eGain Corporation                              1      1                 1
# eTRANSERVICES                                  1      1                 1
# iSite LLC                                      1      1                 1
# mLINQS                                         4      4                 4
#
#                           Authorization Date   Agency   Subagency  \
#  Cloud Service Provider
# 18F                                        1        8           3
# 1901 Group                                 1        2           1
# AINS                                       1       16           5
# AT&T Cybersecurity                         0        1           0
# Accellion USA, LLC.                        1        6           2
# ...                                      ...      ...         ...
# Zscaler                                    2        7           2
# eGain Corporation                          0        1           0
# eTRANSERVICES                              1        1           0
# iSite LLC                                  1        1           0
# mLINQS                                     1        4           2
#
#                           Independent Assessor
#  Cloud Service Provider
# 18F                                          1
# 1901 Group                                   1
# AINS                                         1
# AT&T Cybersecurity                           1
# Accellion USA, LLC.                          1
# ...                                        ...
# Zscaler                                      3
# eGain Corporation                            1
# eTRANSERVICES                                1
# iSite LLC                                    1
# mLINQS                                       1
#
# [237 rows x 7 columns]

# %%
import missingno as msno
# %matplotlib inline
#msno.heatmap(fedramp_df)

# %%
msno.bar(fedramp_df.sample(1169))
# Out:
# <AxesSubplot:>

# %%
msno.matrix(fedramp_df.sample(1169))
# Out:
# <AxesSubplot:>

# %%
msno.dendrogram(fedramp_df)
# Out:
# <AxesSubplot:>

# %%
msno.dendrogram(aws_df)
# Out:
# <AxesSubplot:>

# %%
msno.matrix(aws_df.sample(224))
# Out:
# <AxesSubplot:>

# %%
fedramp_df[fedramp_df[' Cloud Service Provider']=='Microsoft'].count()
# Out:
#  Cloud Service Provider    118
#  Cloud Service Offering    118
#  Type                      118
#  Leveraged A T O           118
#  Authorization Date          3
#  Agency                    118
#  Subagency                  47
#  Independent Assessor        4
# dtype: int64

# %%
fedramp_df[fedramp_df[' Cloud Service Provider']=='Amazon'].count()
# Out:
#  Cloud Service Provider    85
#  Cloud Service Offering    85
#  Type                      85
#  Leveraged A T O           85
#  Authorization Date         2
#  Agency                    85
#  Subagency                 41
#  Independent Assessor       2
# dtype: int64

# %%
fedramp_df[fedramp_df[' Cloud Service Provider']=='Google'].count()
# Out:
#  Cloud Service Provider    12
#  Cloud Service Offering    12
#  Type                      12
#  Leveraged A T O           12
#  Authorization Date         2
#  Agency                    12
#  Subagency                  4
#  Independent Assessor       2
# dtype: int64

# %%
fedramp_df[fedramp_df[' Cloud Service Provider']=='Microsoft']
# Out:
#      Cloud Service Provider                         Cloud Service Offering  \
# 654               Microsoft                         Azure Commercial Cloud
# 655               Microsoft                         Azure Commercial Cloud
# 656               Microsoft                         Azure Commercial Cloud
# 657               Microsoft                         Azure Commercial Cloud
# 658               Microsoft                         Azure Commercial Cloud
# ..                      ...                                            ...
# 767               Microsoft  Office 365 Multi-Tenant & Supporting Services
# 768               Microsoft  Office 365 Multi-Tenant & Supporting Services
# 769               Microsoft  Office 365 Multi-Tenant & Supporting Services
# 770               Microsoft  Office 365 Multi-Tenant & Supporting Services
# 771               Microsoft  Office 365 Multi-Tenant & Supporting Services
#
#        Type  Leveraged A T O  Authorization Date  \
# 654     JAB               No          05/03/2019
# 655     JAB              Yes                 NaN
# 656     JAB              Yes                 NaN
# 657     JAB              Yes                 NaN
# 658     JAB              Yes                 NaN
# ..      ...              ...                 ...
# 767  Agency              Yes                 NaN
# 768  Agency              Yes                 NaN
# 769  Agency              Yes                 NaN
# 770  Agency              Yes                 NaN
# 771  Agency              Yes                 NaN
#
#                                                 Agency  \
# 654                                  JAB Authorization
# 655                     National Labor Relations Board
# 656  Corporation for National & Community Service (...
# 657                        National Science Foundation
# 658                         Department of the Treasury
# ..                                                 ...
# 767                             Department of Commerce
# 768                U.S. Election Assistance Commission
# 769                           Federal Trade Commission
# 770                              Department of Defense
# 771  United States Agency for International Develop...
#
#                                              Subagency  Independent Assessor
# 654                                                NaN                Kratos
# 655                                                NaN                   NaN
# 656                                                NaN                   NaN
# 657                                                NaN                   NaN
# 658                           Internal Revenue Service                   NaN
# ..                                                 ...                   ...
# 767  National Telecommunications and Information Ad...                   NaN
# 768                                                NaN                   NaN
# 769                                                NaN                   NaN
# 770              United States Army Corps of Engineers                   NaN
# 771                                                NaN                   NaN
#
# [118 rows x 8 columns]

# %%
fedramp_df[fedramp_df[' Cloud Service Provider']=='Microsoft'].count()
# Out:
#  Cloud Service Provider    118
#  Cloud Service Offering    118
#  Type                      118
#  Leveraged A T O           118
#  Authorization Date          3
#  Agency                    118
#  Subagency                  47
#  Independent Assessor        4
# dtype: int64

# %%
fedramp_df[fedramp_df[' Cloud Service Provider']=='Amazon']
# Out:
#      Cloud Service Provider  Cloud Service Offering  Type  Leveraged A T O  \
# 96                   Amazon            AWS GovCloud   JAB               No
# 97                   Amazon            AWS GovCloud   JAB              Yes
# 98                   Amazon            AWS GovCloud   JAB              Yes
# 99                   Amazon            AWS GovCloud   JAB              Yes
# 100                  Amazon            AWS GovCloud   JAB              Yes
# ..                      ...                     ...   ...              ...
# 176                  Amazon        AWS US East/West   JAB              Yes
# 177                  Amazon        AWS US East/West   JAB              Yes
# 178                  Amazon        AWS US East/West   JAB              Yes
# 179                  Amazon        AWS US East/West   JAB              Yes
# 180                  Amazon        AWS US East/West   JAB              Yes
#
#      Authorization Date                                             Agency  \
# 96           06/21/2016                                  JAB Authorization
# 97                  NaN            Department of Health and Human Services
# 98                  NaN                     National Labor Relations Board
# 99                  NaN                        National Science Foundation
# 100                 NaN                             Department of Commerce
# ..                  ...                                                ...
# 176                 NaN  United States Agency for International Develop...
# 177                 NaN                                Department of Labor
# 178                 NaN                   Millennium Challenge Corporation
# 179                 NaN                   Millennium Challenge Corporation
# 180                 NaN                              Department of Justice
#
#                      Subagency    Independent Assessor
# 96                         NaN  Coalfire Systems, Inc.
# 97                         NaN                     NaN
# 98                         NaN                     NaN
# 99                         NaN                     NaN
# 100                        NaN                     NaN
# ..                         ...                     ...
# 176                        NaN                     NaN
# 177                        NaN                     NaN
# 178                        NaN                     NaN
# 179                        NaN                     NaN
# 180  Federal Bureau of Prisons                     NaN
#
# [85 rows x 8 columns]

# %%
fedramp_df[fedramp_df[' Cloud Service Provider']=='Amazon'].count()
# Out:
#  Cloud Service Provider    85
#  Cloud Service Offering    85
#  Type                      85
#  Leveraged A T O           85
#  Authorization Date         2
#  Agency                    85
#  Subagency                 41
#  Independent Assessor       2
# dtype: int64

# %%
fedramp_df[fedramp_df[' Cloud Service Provider']=='Google']
# Out:
#      Cloud Service Provider  \
# 471                  Google
# 472                  Google
# 473                  Google
# 474                  Google
# 475                  Google
# 476                  Google
# 477                  Google
# 478                  Google
# 479                  Google
# 480                  Google
# 481                  Google
# 482                  Google
#
#                                 Cloud Service Offering    Type  \
# 471  Google Services (Google Cloud Platform Product...     JAB
# 472  Google Services (Google Cloud Platform Product...     JAB
# 473  Google Services (Google Cloud Platform Product...     JAB
# 474                                   Google Workspace  Agency
# 475                                   Google Workspace  Agency
# 476                                   Google Workspace  Agency
# 477                                   Google Workspace  Agency
# 478                                   Google Workspace  Agency
# 479                                   Google Workspace  Agency
# 480                                   Google Workspace  Agency
# 481                                   Google Workspace  Agency
# 482                                   Google Workspace  Agency
#
#      Leveraged A T O  Authorization Date  \
# 471               No          11/22/2019
# 472              Yes                 NaN
# 473              Yes                 NaN
# 474               No          08/24/2020
# 475              Yes                 NaN
# 476              Yes                 NaN
# 477              Yes                 NaN
# 478              Yes                 NaN
# 479              Yes                 NaN
# 480              Yes                 NaN
# 481              Yes                 NaN
# 482              Yes                 NaN
#
#                                                 Agency  \
# 471                                  JAB Authorization
# 472                             Department of Commerce
# 473                    General Services Administration
# 474                    General Services Administration
# 475       National Archives and Records Administration
# 476                         Department of the Interior
# 477                             Department of Commerce
# 478                               Department of Energy
# 479  United States Agency for International Develop...
# 480                                Library of Congress
# 481                             Department of Commerce
# 482                    General Services Administration
#
#                                            Subagency    Independent Assessor
# 471                                              NaN  Coalfire Systems, Inc.
# 472        United States Patent and Trademark Office                     NaN
# 473                                              NaN                     NaN
# 474                                              NaN  Coalfire Systems, Inc.
# 475                                              NaN                     NaN
# 476                                              NaN                     NaN
# 477   National Institute of Standards and Technology                     NaN
# 478                   Los Alamos National Laboratory                     NaN
# 479                                              NaN                     NaN
# 480                                              NaN                     NaN
# 481  National Oceanic and Atmospheric Administration                     NaN
# 482                                              NaN                     NaN

# %%
fedramp_df[fedramp_df[' Cloud Service Provider']=='Google'].count()
# Out:
#  Cloud Service Provider    12
#  Cloud Service Offering    12
#  Type                      12
#  Leveraged A T O           12
#  Authorization Date         2
#  Agency                    12
#  Subagency                  4
#  Independent Assessor       2
# dtype: int64

# %%
fedramp_april_df = pd.read_csv('data/fedramp-2021-04-30.csv')

# %%
fedramp_april_df
# Out:
#       Cloud Service Provider  \
# 0                        18F
# 1                        18F
# 2                        18F
# 3                        18F
# 4                        18F
# ...                      ...
# 1295                 Zscaler
# 1296                 Zscaler
# 1297                 Zscaler
# 1298                 Zscaler
# 1299                 Zscaler
#
#                                  Cloud Service Offering  Type  Service Model  \
# 0                                         18F Cloud.gov   JAB           PaaS
# 1                                         18F Cloud.gov   JAB           PaaS
# 2                                         18F Cloud.gov   JAB           PaaS
# 3                                         18F Cloud.gov   JAB           PaaS
# 4                                         18F Cloud.gov   JAB           PaaS
# ...                                                 ...   ...            ...
# 1295  Zscaler Private Access – Government (Zero Trus...   JAB           SaaS
# 1296  Zscaler Private Access – Government (Zero Trus...   JAB           SaaS
# 1297  Zscaler Private Access – Government (Zero Trus...   JAB           SaaS
# 1298  Zscaler Private Access – Government (Zero Trus...   JAB           SaaS
# 1299  Zscaler Private Access – Government (Zero Trus...   JAB           SaaS
#
#       Leveraged A T O  Authorization Date  Announcement Date  \
# 0                  No          01/18/2017         02/02/2017
# 1                 Yes                 NaN                NaN
# 2                 Yes                 NaN                NaN
# 3                 Yes                 NaN                NaN
# 4                 Yes                 NaN                NaN
# ...               ...                 ...                ...
# 1295               No          04/21/2020         04/29/2020
# 1296              Yes                 NaN                NaN
# 1297              Yes                 NaN                NaN
# 1298              Yes                 NaN                NaN
# 1299              Yes                 NaN                NaN
#
#                                        Agency  \
# 0                           JAB Authorization
# 1             General Services Administration
# 2       Federal Deposit Insurance Corporation
# 3                       Department of Defense
# 4                  Department of the Treasury
# ...                                       ...
# 1295                        JAB Authorization
# 1296        Federal Communications Commission
# 1297                      Department of State
# 1298                 Federal Trade Commission
# 1299  Department of Health and Human Services
#
#                                        Subagency      Independent Assessor  \
# 0                                            NaN    Coalfire Systems, Inc.
# 1                                            NaN                       NaN
# 2                                            NaN                       NaN
# 3             Defense Information Systems Agency                       NaN
# 4                       Internal Revenue Service                       NaN
# ...                                          ...                       ...
# 1295                                         NaN  Schellman & Company, LLC
# 1296                                         NaN                       NaN
# 1297       State Office of the Inspector General                       NaN
# 1298                                         NaN                       NaN
# 1299  Centers for Disease Control and Prevention                       NaN
#
#         Package Id
# 0      F1607067912
# 1      F1607067912
# 2      F1607067912
# 3      F1607067912
# 4      F1607067912
# ...            ...
# 1295  FR1719759604
# 1296  FR1719759604
# 1297  FR1719759604
# 1298  FR1719759604
# 1299  FR1719759604
#
# [1300 rows x 11 columns]

# %%
fedramp_april_df[fedramp_april_df[' Cloud Service Provider']=='Google'].count()
# Out:
#  Cloud Service Provider    13
#  Cloud Service Offering    13
#  Type                      13
#  Service Model             13
#  Leveraged A T O           13
#  Authorization Date         2
#  Announcement Date          2
#  Agency                    13
#  Subagency                  4
#  Independent Assessor       3
#  Package Id                13
# dtype: int64

# %%
list(fedramp_april_df.columns)
# Out:
# [' Cloud Service Provider',
#  ' Cloud Service Offering',
#  ' Type',
#  ' Service Model',
#  ' Leveraged A T O',
#  ' Authorization Date',
#  ' Announcement Date',
#  ' Agency',
#  ' Subagency',
#  ' Independent Assessor',
#  ' Package Id']

# %%
fedramp_april_df.groupby([' Service Model']).count()
# Out:
#                    Cloud Service Provider   Cloud Service Offering   Type  \
#  Service Model
# IaaS                                   85                       85     83
# IaaS, PaaS                            153                      153    151
# IaaS, PaaS, SaaS                       38                       38     38
# PaaS                                   79                       79     79
# PaaS, SaaS                            136                      136    136
# SaaS                                  809                      809    788
#
#                    Leveraged A T O   Authorization Date   Announcement Date  \
#  Service Model
# IaaS                            85                   10                  10
# IaaS, PaaS                     153                   12                  12
# IaaS, PaaS, SaaS                38                    2                   2
# PaaS                            79                   15                  15
# PaaS, SaaS                     136                   11                  11
# SaaS                           809                  170                 170
#
#                    Agency   Subagency   Independent Assessor   Package Id
#  Service Model
# IaaS                   83          21                     15           85
# IaaS, PaaS            151          65                     14          153
# IaaS, PaaS, SaaS       38          21                      2           38
# PaaS                   79          24                     17           79
# PaaS, SaaS            136          47                     13          136
# SaaS                  788         249                    243          809

# %%
fedramp_april_df.groupby([' Cloud Service Provider']).count()
# Out:
#                           Cloud Service Offering   Type   Service Model  \
#  Cloud Service Provider
# 18F                                           10     10              10
# 1901 Group                                     2      2               2
# AINS                                          20     20              20
# AT&T Cybersecurity                             1      1               1
# Accellion USA, LLC.                            6      6               6
# ...                                          ...    ...             ...
# Zscaler                                       10     10              10
# eGain Corporation                              1      1               1
# eTRANSERVICES                                  1      1               1
# iSite LLC                                      1      1               1
# mLINQS                                         4      4               4
#
#                           Leveraged A T O   Authorization Date  \
#  Cloud Service Provider
# 18F                                    10                    1
# 1901 Group                              2                    1
# AINS                                   20                    1
# AT&T Cybersecurity                      1                    0
# Accellion USA, LLC.                     6                    1
# ...                                   ...                  ...
# Zscaler                                10                    2
# eGain Corporation                       1                    0
# eTRANSERVICES                           1                    1
# iSite LLC                               1                    1
# mLINQS                                  4                    1
#
#                           Announcement Date   Agency   Subagency  \
#  Cloud Service Provider
# 18F                                       1       10           3
# 1901 Group                                1        2           1
# AINS                                      1       20           7
# AT&T Cybersecurity                        0        1           0
# Accellion USA, LLC.                       1        6           2
# ...                                     ...      ...         ...
# Zscaler                                   2       10           4
# eGain Corporation                         0        1           0
# eTRANSERVICES                             1        1           0
# iSite LLC                                 1        1           0
# mLINQS                                    1        4           2
#
#                           Independent Assessor   Package Id
#  Cloud Service Provider
# 18F                                          1           10
# 1901 Group                                   1            2
# AINS                                         1           20
# AT&T Cybersecurity                           1            1
# Accellion USA, LLC.                          1            6
# ...                                        ...          ...
# Zscaler                                      3           10
# eGain Corporation                            1            1
# eTRANSERVICES                                1            1
# iSite LLC                                    1            1
# mLINQS                                       1            4
#
# [247 rows x 10 columns]

# %%
fedramp_april_df.groupby([' Cloud Service Offering']).count()
# Out:
#                                                     Cloud Service Provider  \
#  Cloud Service Offering
# 18F Cloud.gov                                                           10
# AEON                                                                     4
# ARC-P Cloud                                                              8
# AT&T Threat Detection and Response for Government                        1
# AWS GovCloud                                                            38
# ...                                                                    ...
# eCase                                                                   20
# eGain Suite                                                              1
# iSite Contract Management Portal                                         1
# in3sight                                                                 2
# mLINQS Hosting Service                                                   4
#
#                                                     Type   Service Model  \
#  Cloud Service Offering
# 18F Cloud.gov                                         10              10
# AEON                                                   4               4
# ARC-P Cloud                                            8               8
# AT&T Threat Detection and Response for Government      1               1
# AWS GovCloud                                          38              38
# ...                                                  ...             ...
# eCase                                                 20              20
# eGain Suite                                            1               1
# iSite Contract Management Portal                       1               1
# in3sight                                               2               2
# mLINQS Hosting Service                                 4               4
#
#                                                     Leveraged A T O  \
#  Cloud Service Offering
# 18F Cloud.gov                                                    10
# AEON                                                              4
# ARC-P Cloud                                                       8
# AT&T Threat Detection and Response for Government                 1
# AWS GovCloud                                                     38
# ...                                                             ...
# eCase                                                            20
# eGain Suite                                                       1
# iSite Contract Management Portal                                  1
# in3sight                                                          2
# mLINQS Hosting Service                                            4
#
#                                                     Authorization Date  \
#  Cloud Service Offering
# 18F Cloud.gov                                                        1
# AEON                                                                 1
# ARC-P Cloud                                                          1
# AT&T Threat Detection and Response for Government                    0
# AWS GovCloud                                                         1
# ...                                                                ...
# eCase                                                                1
# eGain Suite                                                          0
# iSite Contract Management Portal                                     1
# in3sight                                                             1
# mLINQS Hosting Service                                               1
#
#                                                     Announcement Date  \
#  Cloud Service Offering
# 18F Cloud.gov                                                       1
# AEON                                                                1
# ARC-P Cloud                                                         1
# AT&T Threat Detection and Response for Government                   0
# AWS GovCloud                                                        1
# ...                                                               ...
# eCase                                                               1
# eGain Suite                                                         0
# iSite Contract Management Portal                                    1
# in3sight                                                            1
# mLINQS Hosting Service                                              1
#
#                                                     Agency   Subagency  \
#  Cloud Service Offering
# 18F Cloud.gov                                           10           3
# AEON                                                     4           1
# ARC-P Cloud                                              8           6
# AT&T Threat Detection and Response for Government        1           0
# AWS GovCloud                                            38          19
# ...                                                    ...         ...
# eCase                                                   20           7
# eGain Suite                                              1           0
# iSite Contract Management Portal                         1           0
# in3sight                                                 2           1
# mLINQS Hosting Service                                   4           2
#
#                                                     Independent Assessor  \
#  Cloud Service Offering
# 18F Cloud.gov                                                          1
# AEON                                                                   1
# ARC-P Cloud                                                            1
# AT&T Threat Detection and Response for Government                      1
# AWS GovCloud                                                           1
# ...                                                                  ...
# eCase                                                                  1
# eGain Suite                                                            1
# iSite Contract Management Portal                                       1
# in3sight                                                               1
# mLINQS Hosting Service                                                 1
#
#                                                     Package Id
#  Cloud Service Offering
# 18F Cloud.gov                                               10
# AEON                                                         4
# ARC-P Cloud                                                  8
# AT&T Threat Detection and Response for Government            1
# AWS GovCloud                                                38
# ...                                                        ...
# eCase                                                       20
# eGain Suite                                                  1
# iSite Contract Management Portal                             1
# in3sight                                                     2
# mLINQS Hosting Service                                       4
#
# [306 rows x 10 columns]
