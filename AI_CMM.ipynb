# %% [markdown]
# The [Capability Maturity Model](https://en.wikipedia.org/wiki/Capability_Maturity_Model) was originally developed as a tool for objectively assessing the ability of government contractors' processes to implement a contracted software project. The CMM then grew into the [Capability Maturity Model Integration (CMMI)](https://en.wikipedia.org/wiki/Capability_Maturity_Model_Integration) which is a process level improvement training and appraisal program.
#
# Maturity Models go even deeper than that with the Government Accountability Office with ORGANIZATIONAL
# TRANSFORMATION: [A Framework for Assessing and Improving Enterprise Architecture Management (Version 2.0)](https://www.gao.gov/assets/80/77233.pdf) dated: August 2010
#
# and an associated document ORGANIZATIONAL TRANSFORMATION: [Enterprise Architecture Value Needs to Be Measured and Reported](https://www.gao.gov/assets/650/648827.pdf) dated: September 2012
#
# INFORMATION TECHNOLOGY: [Agencies Need to Develop Modernization Plans for Critical Legacy Systems](https://www.gao.gov/assets/700/699616.pdf)
#
# [General Services Administration’s Unified Shared Services Management’s 5 Modernization and Migration Management (M3) Playbook and M3 Playbook Guidance](https://ussm.gsa.gov/m3/)
#
# [M3 Playbook](https://ussm.gsa.gov/assets/files/2018_M3_Playbook_Final.pdf)

# %% [markdown]
# As congress turns up the heat on making government accountable, how do we benchmark and track progress of modernization efforts with respect to Artificial Intelligence (AI) initiatives?
#
# Why do I bring up AI?
#
# <img src="images/EO13859.png" align="center" alt="EO13859" width = "600">
#
# EO13859 is pursuing five pillars for advancing AI:
# 1. __Invest__ in AI research and development (R&D),
# 2. __Unleash__ AI resources,
# 3. __Remove__ barriers to AI innovation,
# 4. __Train__ an AI-ready workforce, and
# 5. __Promote__ an international environment that is supportive of American AI innovation and its responsible use.
#
# ___The U.S. is also actively leveraging AI to help the Federal government work smarter in its own services and missions in trustworthy ways.___

# %% [markdown]
# When I first arrived we conducted a little bake off on utilizing simple cloud based AI services for
# [Anil's Testimony](https://docs.google.com/presentation/d/1GBEssjy9Eis1dTAsf5PviQde3lxxYG9KT4Oi2S_ODTI/edit#slide=id.p1)
#
# Why are we discussing a model? Because COE will need a way to benchmark and track progress of how well the engagement is progressing with it's IT modernization but also keeping the pulse of the AI push. Let's take a look at this congressional oversight committee ["Making IT a Priority for The Federal Government"](https://drive.google.com/file/d/1llbwlT9CPJo_KrPSUd6Km3KVwcGsJu17/view?usp=sharing)
#
# <img src="images/Congressional_Heat.png" align="center" alt="Mark Meadows" width = "600">
#
#
# The initial thought process was to tie together this idea of setting a baseline and monitoring progress in terms of AI, so we came up with:
#
# ## AI Capability Maturity Model
# One of the largest challenges currently is a realization that organizations performing machine learning, is to have a repeatable and scalable (horizontally and vertically) Machine Learning foundation and process. Herein lies a model that in itself can be adapted and changed over time.
#
# - __Level 0__ - Secure Cloud infrastructure Ability to consistently scale and share AI services and resources horizontally and vertically
# - __Level 1__ - Data Pipeline created with a continuous delivery of data
# - __Level 2__ - Agile Software Development process formed
# - __Level 3__ - Operational requirements process formed
# - __Level 4__ - Ability to conduct Exploratory and Deep Data Analysis and share and catalog results
# - __Level 5__ - Has a Traditional ML Process with ability to measure, share and catalog results
# - __Level 6__ - Has a AutoML Process with ability to measure, share and catalog results
# - __Level 7__ - ML Operational Feedback Loop measures effectiveness
#
# We'll call this AI_CMM version 0.
#
# This idea of a feedback loop turned into the AI Sustainment Cycle shown below:
#
# <img src="images/AI_Sustainment_Cycle.png" align="center" alt="AI_CMM_v1" width = "500">
#
# Once this central idea was captured, we put the idea into the context of a two-dimensional model that CMU CMMI is based on and shown below:
#
# <img src="images/AI_CMM_v1.png" align="center" alt="AI_CMM_v1" width = "600">

# %% [markdown]
# Once we had this model which we'll call version 1, we started to level up the operational maturity, breaking out and adding layers. We now have a version 2 that has a little more meat to it and have 3 questions created for each block. This effort now include a wider array of the COE team to help building it out making it a team effort.
#
# <img src="images/20200921_AI_CMM_v2.png" align="center" alt="AI_CMM_v1" width = "600">

# %% [markdown]
# We have toyed around also with incorporating other layers to it such as T&EOps for those organizations such as DoD, DoE and NASA that incorporate a stringent Test and Evaluation effort.
#
# <img src="images/T&E.png" align="center" alt="AI_CMM_v1" width = "600">

# %% [markdown]
# Once we got here, we starting thinking through the questions we might ask to be able to create a scoring system. We ask 3 questions in each Operational/Organizational block to create sum score horizontally and vertically. We'll call this version 3.
#
# <img src="images/AI_CMM_v3.png" align="center" alt="AI_CMM_v1" width = "600">

# %% [markdown]
# We incorporated a designer on the team to work to make a more readable model fast consumable design where the team had input on.
#
# <img src="images/Design.png" align="center" alt="AI_CMM_v1" width = "600">

# %% [markdown]
# With our engagements I wanted something a little more concrete so I started mapping the AI CMM to the main cloud providers starting with the top and working my way down. Currently according to Gartner AWS, followed by Azure, followed by GCP.
#
# <img src="images/Gartner_cloud.png" align="center" alt="Gartner Cloud Leaders" width = "400">
#
# <img src="images/CloudAI.png" align="center" alt="Gartner Cloud AI Services" width = "400">
#
# <img src="images/AWS_AI_ML_Stack.png" align="center" alt="AWS_AI_CMM_MAP" width = "800">
#
# <img src="images/PeopleOps.png" align="center" alt="PeopleOps" width = "400">

# %% [markdown]
# That's a lot of services, did I get them all?
#
# - [AWS Services](https://docs.google.com/spreadsheets/d/1VgnePn1Im-NaGa3oPofcv7NZzHxz0ny3Q6rjGPh2-vA/edit#gid=1278028925)
# - [Azure Services](https://docs.google.com/spreadsheets/d/1wR9xMezJJmn2LBeMvlWN9uuSTBP0VnBmBmqH-o0_0n8/edit#gid=211060091)
# - [GCP Services](https://docs.google.com/spreadsheets/d/1EpfVAE1daEb_5u4enER9xTMyeYRyO0pKISrsmvEGrOk/edit#gid=442823116)

# %%
import pandas as pd
aws_df = pd.read_csv('data/AWS2.csv')
azure_df = pd.read_csv('data/Azure2.csv')
gcp_df = pd.read_csv('data/GCP.csv')

# %%
aws_df
# Out:
#                             Name  \
# 0             Alexa for Business
# 1             Amazon API Gateway
# 2             Amazon API Gateway
# 3                 Amazon AppFlow
# 4           Amazon AppStream 2.0
# ..                           ...
# 219  Reserved Instance Reporting
# 220                Savings Plans
# 221            TensorFlow on AWS
# 222             VM Import/Export
# 223          VMware Cloud on AWS
#
#                                            Description  \
# 0                 Empower your organization with Alexa
# 1                      Build, deploy, and manage API's
# 2                       Build, deploy, and manage APIs
# 3     No code integration for SaaS apps & AWS services
# 4    Stream desktop applications securely to a browser
# ..                                                 ...
# 219     Dive deeper into your reserved instances (RIs)
# 220  Save up to 72% on compute usage with flexible ...
# 221           Open-source machine intelligence library
# 222  import virtual machine images from your existi...
# 223       Build a hybrid cloud without custom hardware
#
#                         Type FedRAMP Moderate (East/West)  \
# 0      Business Applications                          NaN
# 1                     Mobile                            ✓
# 2                 Networking                            ✓
# 3    Application Integration                          NaN
# 4         End User Computing                            ✓
# ..                       ...                          ...
# 219          Cost Management                          NaN
# 220          Cost Management                          NaN
# 221         Machine Learning                          NaN
# 222                Migration                            ✓
# 223                  Compute                          NaN
#
#     FedRAMP High (GovCloud) DoD CC SRG IL2 (East/West)  \
# 0                       NaN                        NaN
# 1                         ✓                          ✓
# 2                         ✓                          ✓
# 3                       NaN                        NaN
# 4                         ✓                          ✓
# ..                      ...                        ...
# 219                     NaN                        NaN
# 220                     NaN                        NaN
# 221                     NaN                        NaN
# 222                       ✓                          ✓
# 223                     NaN                        NaN
#
#     DoD CC SRG IL2 (GovCloud) DoD CC SRG IL4 (GovCloud)  \
# 0                         NaN                       NaN
# 1                           ✓                         ✓
# 2                           ✓                         ✓
# 3                         NaN                       NaN
# 4                           ✓                         ✓
# ..                        ...                       ...
# 219                       NaN                       NaN
# 220                       NaN                       NaN
# 221                       NaN                       NaN
# 222                         ✓                         ✓
# 223                       NaN                       NaN
#
#     DoD CC SRG IL5 (GovCloud) DoD CC SRG IL6 (AWS Secret Region)
# 0                         NaN                                NaN
# 1                           ✓                                NaN
# 2                           ✓                                NaN
# 3                         NaN                                NaN
# 4                           ✓                                NaN
# ..                        ...                                ...
# 219                       NaN                                NaN
# 220                       NaN                                NaN
# 221                       NaN                                NaN
# 222                         ✓                        DISA Review
# 223                       NaN                                NaN
#
# [224 rows x 10 columns]

# %%
azure_df
# Out:
#                              Name  \
# 0        Anomaly Detector PREVIEW
# 1                        API Apps
# 2                        API Apps
# 3                        API Apps
# 4                  API Management
# ..                            ...
# 332                      Web Apps
# 333  Windows 10 IoT Core Services
# 334       Windows Virtual Desktop
# 335       Windows Virtual Desktop
# 336                       Xamarin
#
#                                            Description  \
# 0    Easily add anomaly detection capabilities to y...
# 1                  Easily build and consume Cloud APIs
# 2                  Easily build and consume Cloud APIs
# 3                  Easily build and consume Cloud APIs
# 4    Publish APIs to developers, partners, and empl...
# ..                                                 ...
# 332  Quickly create and deploy mission critical web...
# 333  Long-term OS support and services to manage de...
# 334  The best virtual desktop experience, delivered...
# 335  The best virtual desktop experience, delivered...
# 336            Create cloud-powered mobile apps faster
#
#                         Type FedRAMP Moderate FedRAMP High Planned 2020  \
# 0           Machine Learning              NaN          NaN          NaN
# 1                    Compute              NaN          NaN          NaN
# 2                 Containers              NaN          NaN          NaN
# 3                        Web              NaN          NaN          NaN
# 4                Integration               ✔️           ✔️          NaN
# ..                       ...              ...          ...          ...
# 332                      Web               ✔️           ✔️          NaN
# 333                      IoT              NaN          NaN          NaN
# 334                  Compute               ✔️           ✔️          NaN
# 335  Windows Virtual Desktop               ✔️           ✔️          NaN
# 336                   Mobile              NaN          NaN          NaN
#
#     DISA IL 2 DISA IL 4 DISA IL 5 ** DISA IL 6
# 0         NaN       NaN          NaN       NaN
# 1         NaN       NaN          NaN       NaN
# 2         NaN       NaN          NaN       NaN
# 3         NaN       NaN          NaN       NaN
# 4          ✔️        ✔️           ✔️       NaN
# ..        ...       ...          ...       ...
# 332        ✔️        ✔️           ✔️        ✔️
# 333       NaN       NaN          NaN       NaN
# 334       NaN       NaN          NaN       NaN
# 335       NaN       NaN          NaN       NaN
# 336       NaN       NaN          NaN       NaN
#
# [337 rows x 10 columns]

# %%
gcp_df
# Out:
#                            Name  \
# 0                      BigQuery
# 1                Cloud Composer
# 2             Cloud Data Fusion
# 3    Cloud Life Sciences (beta)
# 4                  Data Catalog
# ..                          ...
# 169        Google Maps Platform
# 170                        Meet
# 171         Phishing Protection
# 172        reCAPTCHA Enterprise
# 173                    Web Risk
#
#                                            Description  \
# 0    Data warehouse for business agility and insights.
# 1    Workflow orchestration service built on Apache...
# 2    Data integration for building and managing dat...
# 3    Tools for managing, processing, and transformi...
# 4    Metadata solution for exploring and managing d...
# ..                                                 ...
# 169  Create immersive location experiences and impr...
# 170                       Easy-to-join video meetings.
# 171            Protect your users from phishing sites.
# 172  Help protect your website from fraudulent acti...
# 173  Detect malicious URLs on your website and in c...
#
#                          Type
# 0                   Analytics
# 1                   Analytics
# 2                   Analytics
# 3                   Analytics
# 4                   Analytics
# ..                        ...
# 169                 User Apps
# 170                 User Apps
# 171  User Protection Services
# 172  User Protection Services
# 173  User Protection Services
#
# [174 rows x 3 columns]

# %%
print("AWS has: ", aws_df['Name'].nunique(),"unique services")
# Out:
# AWS has:  213 unique services

# %%
print("Azure has: ", azure_df['Name'].nunique(),"unique services")
# Out:
# Azure has:  256 unique services

# %%
print("GCP has: ", gcp_df['Name'].nunique(),"unique services")
# Out:
# GCP has:  158 unique services

# %%
aws_type = aws_df.groupby(['Type']).count()
aws_type
# Out:
#                                  Name  Description  \
# Type
# AR & VR                             1            1
# Analytics                          14           14
# Application Integration             7            7
# Blockchain                          2            2
# Business Applications               5            5
# Compute                            13           13
# Containers                          5            5
# Cost Management                     5            5
# Customer Engagement                 4            4
# Databases                          19           19
# Developer Tools                    15           15
# End User Computing                  4            4
# Game Tech                           2            2
# IoT                                12           12
# Machine Learning                   25           25
# Management & Governance            22           22
# Media                              10           10
# Migration                          11           11
# Mobile                              5            5
# Networking                         12           12
# Quantum                             1            1
# Robotics                            1            1
# Satellite                           1            1
# Security, Identity & Compliance    18           18
# Storage                            10           10
#
#                                  FedRAMP Moderate (East/West)  \
# Type
# AR & VR                                                     0
# Analytics                                                   8
# Application Integration                                     4
# Blockchain                                                  0
# Business Applications                                       2
# Compute                                                     9
# Containers                                                  4
# Cost Management                                             0
# Customer Engagement                                         3
# Databases                                                  11
# Developer Tools                                             4
# End User Computing                                          3
# Game Tech                                                   0
# IoT                                                         3
# Machine Learning                                            7
# Management & Governance                                    13
# Media                                                       1
# Migration                                                   5
# Mobile                                                      2
# Networking                                                  8
# Quantum                                                     0
# Robotics                                                    0
# Satellite                                                   0
# Security, Identity & Compliance                            11
# Storage                                                     4
#
#                                  FedRAMP High (GovCloud)  \
# Type
# AR & VR                                                0
# Analytics                                              7
# Application Integration                                3
# Blockchain                                             0
# Business Applications                                  0
# Compute                                                9
# Containers                                             4
# Cost Management                                        0
# Customer Engagement                                    1
# Databases                                             11
# Developer Tools                                        4
# End User Computing                                     3
# Game Tech                                              0
# IoT                                                    3
# Machine Learning                                       7
# Management & Governance                               11
# Media                                                  1
# Migration                                              5
# Mobile                                                 2
# Networking                                             6
# Quantum                                                0
# Robotics                                               0
# Satellite                                              0
# Security, Identity & Compliance                        8
# Storage                                                5
#
#                                  DoD CC SRG IL2 (East/West)  \
# Type
# AR & VR                                                   0
# Analytics                                                 8
# Application Integration                                   4
# Blockchain                                                0
# Business Applications                                     2
# Compute                                                   9
# Containers                                                4
# Cost Management                                           1
# Customer Engagement                                       3
# Databases                                                10
# Developer Tools                                           4
# End User Computing                                        3
# Game Tech                                                 0
# IoT                                                       3
# Machine Learning                                          6
# Management & Governance                                  13
# Media                                                     1
# Migration                                                 5
# Mobile                                                    2
# Networking                                                8
# Quantum                                                   1
# Robotics                                                  0
# Satellite                                                 0
# Security, Identity & Compliance                          12
# Storage                                                   5
#
#                                  DoD CC SRG IL2 (GovCloud)  \
# Type
# AR & VR                                                  0
# Analytics                                                7
# Application Integration                                  3
# Blockchain                                               0
# Business Applications                                    0
# Compute                                                  9
# Containers                                               4
# Cost Management                                          0
# Customer Engagement                                      1
# Databases                                               10
# Developer Tools                                          4
# End User Computing                                       3
# Game Tech                                                0
# IoT                                                      3
# Machine Learning                                         6
# Management & Governance                                 11
# Media                                                    1
# Migration                                                5
# Mobile                                                   2
# Networking                                               7
# Quantum                                                  1
# Robotics                                                 0
# Satellite                                                0
# Security, Identity & Compliance                          9
# Storage                                                  5
#
#                                  DoD CC SRG IL4 (GovCloud)  \
# Type
# AR & VR                                                  0
# Analytics                                                7
# Application Integration                                  3
# Blockchain                                               0
# Business Applications                                    0
# Compute                                                  9
# Containers                                               4
# Cost Management                                          0
# Customer Engagement                                      1
# Databases                                                9
# Developer Tools                                          4
# End User Computing                                       3
# Game Tech                                                0
# IoT                                                      3
# Machine Learning                                         6
# Management & Governance                                 11
# Media                                                    1
# Migration                                                5
# Mobile                                                   2
# Networking                                               7
# Quantum                                                  1
# Robotics                                                 0
# Satellite                                                0
# Security, Identity & Compliance                          9
# Storage                                                  5
#
#                                  DoD CC SRG IL5 (GovCloud)  \
# Type
# AR & VR                                                  0
# Analytics                                                7
# Application Integration                                  3
# Blockchain                                               0
# Business Applications                                    0
# Compute                                                  9
# Containers                                               4
# Cost Management                                          0
# Customer Engagement                                      1
# Databases                                               10
# Developer Tools                                          4
# End User Computing                                       3
# Game Tech                                                0
# IoT                                                      3
# Machine Learning                                         6
# Management & Governance                                 11
# Media                                                    1
# Migration                                                5
# Mobile                                                   2
# Networking                                               7
# Quantum                                                  1
# Robotics                                                 0
# Satellite                                                0
# Security, Identity & Compliance                          9
# Storage                                                  5
#
#                                  DoD CC SRG IL6 (AWS Secret Region)
# Type
# AR & VR                                                           0
# Analytics                                                         3
# Application Integration                                           3
# Blockchain                                                        0
# Business Applications                                             0
# Compute                                                           5
# Containers                                                        0
# Cost Management                                                   0
# Customer Engagement                                               0
# Databases                                                         8
# Developer Tools                                                   2
# End User Computing                                                0
# Game Tech                                                         0
# IoT                                                               0
# Machine Learning                                                  0
# Management & Governance                                           9
# Media                                                             0
# Migration                                                         2
# Mobile                                                            0
# Networking                                                        5
# Quantum                                                           0
# Robotics                                                          0
# Satellite                                                         0
# Security, Identity & Compliance                                   2
# Storage                                                           3

# %%
aws_IL6 = aws_df['DoD CC SRG IL6 (AWS Secret Region)']
aws_IL6.count()
# Out:
# 42

# %%
azure_IL6 = azure_df['DISA IL 6']
azure_IL6.count()
# Out:
# 50

# %%
aws_IL5 = aws_df['DoD CC SRG IL5 (GovCloud)']
aws_IL5.count()
# Out:
# 91

# %%
azure_IL6 = azure_df['DISA IL 5 **']
azure_IL6.count()
# Out:
# 69

# %%
azure_type = azure_df.groupby(['Type']).count()
azure_type
# Out:
#                          Name  Description  FedRAMP Moderate  FedRAMP High  \
# Type
# Analytics                  20           20                12            12
# Blockchain                  5            5                 2             2
# Compute                    21           21                 9             9
# Containers                 10           10                 6             6
# Customer Service           11           11                 5             5
# Databases                  14           14                 9             9
# DevOps                      9            9                 1             1
# Developer Tools            16           16                 7             7
# Hybrid                     13           13                 5             5
# Identity                    8            8                 6             6
# Integration                 6            6                 4             4
# IoT                        21           21                 8             8
# Machine Learning           51           51                17            17
# Management & Governance    23           23                20            20
# Media                       8            8                 2             2
# Migration                   7            7                 6             6
# Mixed Reality               4            4                 0             0
# Mobile                      9            9                 4             4
# Networking                 21           21                18            18
# Security                   23           23                19            19
# Storage                    23           23                13            13
# Web                        13           13                 7             7
# Windows Virtual Desktop     1            1                 1             1
#
#                          Planned 2020  DISA IL 2  DISA IL 4  DISA IL 5 **  \
# Type
# Analytics                           2         13         11             6
# Blockchain                          0          2          2             1
# Compute                             0          7          7             6
# Containers                          0          5          4             2
# Customer Service                    0          8          2             0
# Databases                           0          8          8             6
# DevOps                              1          2          2             1
# Developer Tools                     2          6          6             4
# Hybrid                              0          4          1             1
# Identity                            0          4          4             2
# Integration                         0          4          4             2
# IoT                                 1          7          5             1
# Machine Learning                    4         15         10             0
# Management & Governance             0         19         19             8
# Media                               0          2          1             1
# Migration                           0          5          5             2
# Mixed Reality                       0          0          0             0
# Mobile                              0          4          4             1
# Networking                          0         15         11            11
# Security                            0         19         15             5
# Storage                             1         12         10             7
# Web                                 0          7          5             2
# Windows Virtual Desktop             0          0          0             0
#
#                          DISA IL 6
# Type
# Analytics                        2
# Blockchain                       2
# Compute                          6
# Containers                       2
# Customer Service                 0
# Databases                        3
# DevOps                           0
# Developer Tools                  2
# Hybrid                           1
# Identity                         2
# Integration                      2
# IoT                              1
# Machine Learning                 0
# Management & Governance          6
# Media                            0
# Migration                        0
# Mixed Reality                    0
# Mobile                           0
# Networking                       8
# Security                         5
# Storage                          7
# Web                              1
# Windows Virtual Desktop          0

# %%
gcp_type = gcp_df.groupby(['Type']).count()
gcp_type
# Out:
#                             Name  Description
# Type
# API Management                12           12
# Analytics                     12           12
# Compute                       12           12
# Containers                     9            9
# Databases                      6            6
# Developer Tools               15           15
# Game Tech                      1            1
# Healthcare & Life Sciences     3            3
# Hybrid & Multi-cloud           4            4
# Identity & Access             10           10
# IoT                            2            2
# Machine Learning              20           20
# Management & Governance        8            8
# Media                          2            2
# Migration                      8            8
# Networking                    12           12
# Operations                     6            6
# Security & Identity           13           13
# Serverless Computing           4            4
# Storage                        8            8
# User Apps                      4            4
# User Protection Services       3            3

# %%
print("AWS has: ", aws_df['Type'].nunique(),"unique types of services")
# Out:
# AWS has:  25 unique types of services

# %%
print("Azure has: ", azure_df['Type'].nunique(),"unique types of services")
# Out:
# Azure has:  23 unique types of services

# %%
print("GCP has: ", gcp_df['Type'].nunique(),"unique types of services")
# Out:
# GCP has:  22 unique types of services

# %%
def dataframe_difference(df1, df2, which=None):
    """Find rows which are different between two DataFrames."""
    comparison_df = df1.merge(df2,
                              indicator=True,
                              how='outer')
    if which is None:
        diff_df = comparison_df[comparison_df['_merge'] != 'both']
    else:
        diff_df = comparison_df[comparison_df['_merge'] == which]
    diff_df.to_csv('data/diff.csv')
    return diff_df

# %%
#dataframe_difference(aws_df.groupby(['Type']), azure_df.groupby(['Type']))
aws_type
# Out:
#                                  Name  Description  \
# Type
# AR & VR                             1            1
# Analytics                          14           14
# Application Integration             7            7
# Blockchain                          2            2
# Business Applications               5            5
# Compute                            13           13
# Containers                          5            5
# Cost Management                     5            5
# Customer Engagement                 4            4
# Databases                          19           19
# Developer Tools                    15           15
# End User Computing                  4            4
# Game Tech                           2            2
# IoT                                12           12
# Machine Learning                   25           25
# Management & Governance            22           22
# Media                              10           10
# Migration                          11           11
# Mobile                              5            5
# Networking                         12           12
# Quantum                             1            1
# Robotics                            1            1
# Satellite                           1            1
# Security, Identity & Compliance    18           18
# Storage                            10           10
#
#                                  FedRAMP Moderate (East/West)  \
# Type
# AR & VR                                                     0
# Analytics                                                   8
# Application Integration                                     4
# Blockchain                                                  0
# Business Applications                                       2
# Compute                                                     9
# Containers                                                  4
# Cost Management                                             0
# Customer Engagement                                         3
# Databases                                                  11
# Developer Tools                                             4
# End User Computing                                          3
# Game Tech                                                   0
# IoT                                                         3
# Machine Learning                                            7
# Management & Governance                                    13
# Media                                                       1
# Migration                                                   5
# Mobile                                                      2
# Networking                                                  8
# Quantum                                                     0
# Robotics                                                    0
# Satellite                                                   0
# Security, Identity & Compliance                            11
# Storage                                                     4
#
#                                  FedRAMP High (GovCloud)  \
# Type
# AR & VR                                                0
# Analytics                                              7
# Application Integration                                3
# Blockchain                                             0
# Business Applications                                  0
# Compute                                                9
# Containers                                             4
# Cost Management                                        0
# Customer Engagement                                    1
# Databases                                             11
# Developer Tools                                        4
# End User Computing                                     3
# Game Tech                                              0
# IoT                                                    3
# Machine Learning                                       7
# Management & Governance                               11
# Media                                                  1
# Migration                                              5
# Mobile                                                 2
# Networking                                             6
# Quantum                                                0
# Robotics                                               0
# Satellite                                              0
# Security, Identity & Compliance                        8
# Storage                                                5
#
#                                  DoD CC SRG IL2 (East/West)  \
# Type
# AR & VR                                                   0
# Analytics                                                 8
# Application Integration                                   4
# Blockchain                                                0
# Business Applications                                     2
# Compute                                                   9
# Containers                                                4
# Cost Management                                           1
# Customer Engagement                                       3
# Databases                                                10
# Developer Tools                                           4
# End User Computing                                        3
# Game Tech                                                 0
# IoT                                                       3
# Machine Learning                                          6
# Management & Governance                                  13
# Media                                                     1
# Migration                                                 5
# Mobile                                                    2
# Networking                                                8
# Quantum                                                   1
# Robotics                                                  0
# Satellite                                                 0
# Security, Identity & Compliance                          12
# Storage                                                   5
#
#                                  DoD CC SRG IL2 (GovCloud)  \
# Type
# AR & VR                                                  0
# Analytics                                                7
# Application Integration                                  3
# Blockchain                                               0
# Business Applications                                    0
# Compute                                                  9
# Containers                                               4
# Cost Management                                          0
# Customer Engagement                                      1
# Databases                                               10
# Developer Tools                                          4
# End User Computing                                       3
# Game Tech                                                0
# IoT                                                      3
# Machine Learning                                         6
# Management & Governance                                 11
# Media                                                    1
# Migration                                                5
# Mobile                                                   2
# Networking                                               7
# Quantum                                                  1
# Robotics                                                 0
# Satellite                                                0
# Security, Identity & Compliance                          9
# Storage                                                  5
#
#                                  DoD CC SRG IL4 (GovCloud)  \
# Type
# AR & VR                                                  0
# Analytics                                                7
# Application Integration                                  3
# Blockchain                                               0
# Business Applications                                    0
# Compute                                                  9
# Containers                                               4
# Cost Management                                          0
# Customer Engagement                                      1
# Databases                                                9
# Developer Tools                                          4
# End User Computing                                       3
# Game Tech                                                0
# IoT                                                      3
# Machine Learning                                         6
# Management & Governance                                 11
# Media                                                    1
# Migration                                                5
# Mobile                                                   2
# Networking                                               7
# Quantum                                                  1
# Robotics                                                 0
# Satellite                                                0
# Security, Identity & Compliance                          9
# Storage                                                  5
#
#                                  DoD CC SRG IL5 (GovCloud)  \
# Type
# AR & VR                                                  0
# Analytics                                                7
# Application Integration                                  3
# Blockchain                                               0
# Business Applications                                    0
# Compute                                                  9
# Containers                                               4
# Cost Management                                          0
# Customer Engagement                                      1
# Databases                                               10
# Developer Tools                                          4
# End User Computing                                       3
# Game Tech                                                0
# IoT                                                      3
# Machine Learning                                         6
# Management & Governance                                 11
# Media                                                    1
# Migration                                                5
# Mobile                                                   2
# Networking                                               7
# Quantum                                                  1
# Robotics                                                 0
# Satellite                                                0
# Security, Identity & Compliance                          9
# Storage                                                  5
#
#                                  DoD CC SRG IL6 (AWS Secret Region)
# Type
# AR & VR                                                           0
# Analytics                                                         3
# Application Integration                                           3
# Blockchain                                                        0
# Business Applications                                             0
# Compute                                                           5
# Containers                                                        0
# Cost Management                                                   0
# Customer Engagement                                               0
# Databases                                                         8
# Developer Tools                                                   2
# End User Computing                                                0
# Game Tech                                                         0
# IoT                                                               0
# Machine Learning                                                  0
# Management & Governance                                           9
# Media                                                             0
# Migration                                                         2
# Mobile                                                            0
# Networking                                                        5
# Quantum                                                           0
# Robotics                                                          0
# Satellite                                                         0
# Security, Identity & Compliance                                   2
# Storage                                                           3

# %%
aws_df.groupby(['Type']).count()
# Out:
#                                  Name  Description  \
# Type
# AR & VR                             1            1
# Analytics                          14           14
# Application Integration             7            7
# Blockchain                          2            2
# Business Applications               5            5
# Compute                            13           13
# Containers                          5            5
# Cost Management                     5            5
# Customer Engagement                 4            4
# Databases                          19           19
# Developer Tools                    15           15
# End User Computing                  4            4
# Game Tech                           2            2
# IoT                                12           12
# Machine Learning                   25           25
# Management & Governance            22           22
# Media                              10           10
# Migration                          11           11
# Mobile                              5            5
# Networking                         12           12
# Quantum                             1            1
# Robotics                            1            1
# Satellite                           1            1
# Security, Identity & Compliance    18           18
# Storage                            10           10
#
#                                  FedRAMP Moderate (East/West)  \
# Type
# AR & VR                                                     0
# Analytics                                                   8
# Application Integration                                     4
# Blockchain                                                  0
# Business Applications                                       2
# Compute                                                     9
# Containers                                                  4
# Cost Management                                             0
# Customer Engagement                                         3
# Databases                                                  11
# Developer Tools                                             4
# End User Computing                                          3
# Game Tech                                                   0
# IoT                                                         3
# Machine Learning                                            7
# Management & Governance                                    13
# Media                                                       1
# Migration                                                   5
# Mobile                                                      2
# Networking                                                  8
# Quantum                                                     0
# Robotics                                                    0
# Satellite                                                   0
# Security, Identity & Compliance                            11
# Storage                                                     4
#
#                                  FedRAMP High (GovCloud)  \
# Type
# AR & VR                                                0
# Analytics                                              7
# Application Integration                                3
# Blockchain                                             0
# Business Applications                                  0
# Compute                                                9
# Containers                                             4
# Cost Management                                        0
# Customer Engagement                                    1
# Databases                                             11
# Developer Tools                                        4
# End User Computing                                     3
# Game Tech                                              0
# IoT                                                    3
# Machine Learning                                       7
# Management & Governance                               11
# Media                                                  1
# Migration                                              5
# Mobile                                                 2
# Networking                                             6
# Quantum                                                0
# Robotics                                               0
# Satellite                                              0
# Security, Identity & Compliance                        8
# Storage                                                5
#
#                                  DoD CC SRG IL2 (East/West)  \
# Type
# AR & VR                                                   0
# Analytics                                                 8
# Application Integration                                   4
# Blockchain                                                0
# Business Applications                                     2
# Compute                                                   9
# Containers                                                4
# Cost Management                                           1
# Customer Engagement                                       3
# Databases                                                10
# Developer Tools                                           4
# End User Computing                                        3
# Game Tech                                                 0
# IoT                                                       3
# Machine Learning                                          6
# Management & Governance                                  13
# Media                                                     1
# Migration                                                 5
# Mobile                                                    2
# Networking                                                8
# Quantum                                                   1
# Robotics                                                  0
# Satellite                                                 0
# Security, Identity & Compliance                          12
# Storage                                                   5
#
#                                  DoD CC SRG IL2 (GovCloud)  \
# Type
# AR & VR                                                  0
# Analytics                                                7
# Application Integration                                  3
# Blockchain                                               0
# Business Applications                                    0
# Compute                                                  9
# Containers                                               4
# Cost Management                                          0
# Customer Engagement                                      1
# Databases                                               10
# Developer Tools                                          4
# End User Computing                                       3
# Game Tech                                                0
# IoT                                                      3
# Machine Learning                                         6
# Management & Governance                                 11
# Media                                                    1
# Migration                                                5
# Mobile                                                   2
# Networking                                               7
# Quantum                                                  1
# Robotics                                                 0
# Satellite                                                0
# Security, Identity & Compliance                          9
# Storage                                                  5
#
#                                  DoD CC SRG IL4 (GovCloud)  \
# Type
# AR & VR                                                  0
# Analytics                                                7
# Application Integration                                  3
# Blockchain                                               0
# Business Applications                                    0
# Compute                                                  9
# Containers                                               4
# Cost Management                                          0
# Customer Engagement                                      1
# Databases                                                9
# Developer Tools                                          4
# End User Computing                                       3
# Game Tech                                                0
# IoT                                                      3
# Machine Learning                                         6
# Management & Governance                                 11
# Media                                                    1
# Migration                                                5
# Mobile                                                   2
# Networking                                               7
# Quantum                                                  1
# Robotics                                                 0
# Satellite                                                0
# Security, Identity & Compliance                          9
# Storage                                                  5
#
#                                  DoD CC SRG IL5 (GovCloud)  \
# Type
# AR & VR                                                  0
# Analytics                                                7
# Application Integration                                  3
# Blockchain                                               0
# Business Applications                                    0
# Compute                                                  9
# Containers                                               4
# Cost Management                                          0
# Customer Engagement                                      1
# Databases                                               10
# Developer Tools                                          4
# End User Computing                                       3
# Game Tech                                                0
# IoT                                                      3
# Machine Learning                                         6
# Management & Governance                                 11
# Media                                                    1
# Migration                                                5
# Mobile                                                   2
# Networking                                               7
# Quantum                                                  1
# Robotics                                                 0
# Satellite                                                0
# Security, Identity & Compliance                          9
# Storage                                                  5
#
#                                  DoD CC SRG IL6 (AWS Secret Region)
# Type
# AR & VR                                                           0
# Analytics                                                         3
# Application Integration                                           3
# Blockchain                                                        0
# Business Applications                                             0
# Compute                                                           5
# Containers                                                        0
# Cost Management                                                   0
# Customer Engagement                                               0
# Databases                                                         8
# Developer Tools                                                   2
# End User Computing                                                0
# Game Tech                                                         0
# IoT                                                               0
# Machine Learning                                                  0
# Management & Governance                                           9
# Media                                                             0
# Migration                                                         2
# Mobile                                                            0
# Networking                                                        5
# Quantum                                                           0
# Robotics                                                          0
# Satellite                                                         0
# Security, Identity & Compliance                                   2
# Storage                                                           3

# %%
fedramp_df = pd.read_csv('data/fedramp-2020-09-29.csv')

# %%
fedramp_df
# Out:
#                              Cloud Service Provider  \
# 0                                         Microsoft
# 1                                       CGI Federal
# 2                                               IBM
# 3                                          Granicus
# 4                                         MicroPact
# ...                                             ...
# 1425                                     ServiceNow
# 1426                                          Okta
# 1427                            Accellion USA, LLC.
# 1428                             Cisco Systems Inc.
# 1429  SAP National Security Services Inc. (SAP NS2)
#
#                                 Cloud Service Offering    Type  \
# 0             Azure Government (includes Dynamics 365)     JAB
# 1                                       CGI IaaS Cloud     JAB
# 2     IBM Maximo and TRIRIGA on Cloud for U.S. Federal  Agency
# 3                     GovDelivery Communications Cloud     JAB
# 4                              MicroPact Product Suite  Agency
# ...                                                ...     ...
# 1425                        Government Community Cloud     JAB
# 1426         Okta IDaaS Regulated Cloud (Moderate IL2)  Agency
# 1427                           Kiteworks Federal Cloud  Agency
# 1428                                       Cisco WebEx  Agency
# 1429              SAP NS2 Cloud Intelligent Enterprise     JAB
#
#       Leveraged A T O  Authorization Date  \
# 0                 Yes                 NaN
# 1                 Yes                 NaN
# 2                 Yes                 NaN
# 3                 Yes                 NaN
# 4                 Yes                 NaN
# ...               ...                 ...
# 1425              Yes                 NaN
# 1426              Yes                 NaN
# 1427              Yes                 NaN
# 1428              Yes                 NaN
# 1429              Yes                 NaN
#
#                                                  Agency  \
# 0               Department of Health and Human Services
# 1     Administrative Office of the United States Courts
# 2     Administrative Office of the United States Courts
# 3               Department of Health and Human Services
# 4                                   Department of Labor
# ...                                                 ...
# 1425           Universal Service Administrative Company
# 1426           Universal Service Administrative Company
# 1427                     Department of Veterans Affairs
# 1428                     Department of Veterans Affairs
# 1429                              Department of Defense
#
#                                        Subagency  Independent Assessor
# 0         Administration for Children & Families                   NaN
# 1                                            NaN                   NaN
# 2                                            NaN                   NaN
# 3     Agency for Healthcare Research and Quality                   NaN
# 4                          Benefits Review Board                   NaN
# ...                                          ...                   ...
# 1425                                         NaN                   NaN
# 1426                                         NaN                   NaN
# 1427          VA Office of the Inspector General                   NaN
# 1428          VA Office of the Inspector General                   NaN
# 1429            Washington Headquarters Services                   NaN
#
# [1430 rows x 8 columns]

# %%
fedramp_df.describe()
# Out:
#         Cloud Service Provider                         Cloud Service Offering  \
# count                     1430                                           1430
# unique                     194                                            244
# top                  Microsoft  Office 365 Multi-Tenant & Supporting Services
# freq                       164                                             78
#
#           Type  Leveraged A T O  Authorization Date  \
# count     1430             1430                 161
# unique       2                2                 139
# top     Agency              Yes          06/12/2019
# freq       858             1224                   3
#
#                                          Agency  \
# count                                      1430
# unique                                       75
# top     Department of Health and Human Services
# freq                                        146
#
#                                  Subagency    Independent Assessor
# count                                  728                     203
# unique                                  82                      24
# top     Defense Information Systems Agency  Coalfire Systems, Inc.
# freq                                    46                      69

# %%
fedramp_df.head()
# Out:
#    Cloud Service Provider                            Cloud Service Offering  \
# 0               Microsoft          Azure Government (includes Dynamics 365)
# 1             CGI Federal                                    CGI IaaS Cloud
# 2                     IBM  IBM Maximo and TRIRIGA on Cloud for U.S. Federal
# 3                Granicus                  GovDelivery Communications Cloud
# 4               MicroPact                           MicroPact Product Suite
#
#      Type  Leveraged A T O  Authorization Date  \
# 0     JAB              Yes                 NaN
# 1     JAB              Yes                 NaN
# 2  Agency              Yes                 NaN
# 3     JAB              Yes                 NaN
# 4  Agency              Yes                 NaN
#
#                                               Agency  \
# 0            Department of Health and Human Services
# 1  Administrative Office of the United States Courts
# 2  Administrative Office of the United States Courts
# 3            Department of Health and Human Services
# 4                                Department of Labor
#
#                                     Subagency  Independent Assessor
# 0      Administration for Children & Families                   NaN
# 1                                         NaN                   NaN
# 2                                         NaN                   NaN
# 3  Agency for Healthcare Research and Quality                   NaN
# 4                       Benefits Review Board                   NaN

# %%
list(fedramp_df.columns)
# Out:
# [' Cloud Service Provider',
#  ' Cloud Service Offering',
#  ' Type',
#  ' Leveraged A T O',
#  ' Authorization Date',
#  ' Agency',
#  ' Subagency',
#  ' Independent Assessor']

# %%
fedramp_df.groupby([' Cloud Service Provider']).count()
# Out:
#                           Cloud Service Offering   Type   Leveraged A T O  \
#  Cloud Service Provider
# 18F                                           11     11                11
# 1901 Group                                     3      3                 3
# AINS                                          19     19                19
# AT&T Cybersecurity                             1      1                 1
# Accellion USA, LLC.                            7      7                 7
# ...                                          ...    ...               ...
# Zscaler                                        8      8                 8
# eGain Corporation                              1      1                 1
# eTRANSERVICES                                  1      1                 1
# iSite LLC                                      1      1                 1
# mLINQS                                         6      6                 6
#
#                           Authorization Date   Agency   Subagency  \
#  Cloud Service Provider
# 18F                                        0       11           6
# 1901 Group                                 1        3           2
# AINS                                       1       19          10
# AT&T Cybersecurity                         0        1           0
# Accellion USA, LLC.                        1        7           4
# ...                                      ...      ...         ...
# Zscaler                                    1        8           4
# eGain Corporation                          0        1           0
# eTRANSERVICES                              1        1           0
# iSite LLC                                  1        1           0
# mLINQS                                     1        6           4
#
#                           Independent Assessor
#  Cloud Service Provider
# 18F                                          0
# 1901 Group                                   1
# AINS                                         1
# AT&T Cybersecurity                           1
# Accellion USA, LLC.                          1
# ...                                        ...
# Zscaler                                      2
# eGain Corporation                            1
# eTRANSERVICES                                1
# iSite LLC                                    1
# mLINQS                                       1
#
# [194 rows x 7 columns]

# %%
import missingno as msno
# %matplotlib inline
#msno.heatmap(fedramp_df)

# %%
msno.bar(fedramp_df.sample(1430))
# Out:
# <AxesSubplot:>

# %%
msno.matrix(fedramp_df.sample(1430))
# Out:
# <AxesSubplot:>

# %%
msno.dendrogram(fedramp_df)
# Out:
# <AxesSubplot:>

# %%
msno.dendrogram(aws_df)
# Out:
# <AxesSubplot:>

# %%
msno.matrix(aws_df.sample(224))
# Out:
# <AxesSubplot:>

# %%
fedramp_df[fedramp_df[' Cloud Service Provider']=='Microsoft'].count()
# Out:
#  Cloud Service Provider    164
#  Cloud Service Offering    164
#  Type                      164
#  Leveraged A T O           164
#  Authorization Date          1
#  Agency                    164
#  Subagency                  96
#  Independent Assessor        2
# dtype: int64

# %%
fedramp_df[fedramp_df[' Cloud Service Provider']=='Amazon'].count()
# Out:
#  Cloud Service Provider    122
#  Cloud Service Offering    122
#  Type                      122
#  Leveraged A T O           122
#  Authorization Date          0
#  Agency                    122
#  Subagency                  82
#  Independent Assessor        0
# dtype: int64

# %%
fedramp_df[fedramp_df[' Cloud Service Provider']=='Google'].count()
# Out:
#  Cloud Service Provider    15
#  Cloud Service Offering    15
#  Type                      15
#  Leveraged A T O           15
#  Authorization Date         1
#  Agency                    15
#  Subagency                  8
#  Independent Assessor       1
# dtype: int64

# %%
fedramp_df[fedramp_df[' Cloud Service Provider']=='Microsoft']
# Out:
#       Cloud Service Provider                         Cloud Service Offering  \
# 0                  Microsoft       Azure Government (includes Dynamics 365)
# 12                 Microsoft       Azure Government (includes Dynamics 365)
# 18                 Microsoft       Azure Government (includes Dynamics 365)
# 31                 Microsoft  Office 365 Multi-Tenant & Supporting Services
# 36                 Microsoft                         Azure Commercial Cloud
# ...                      ...                                            ...
# 1384               Microsoft  Office 365 Multi-Tenant & Supporting Services
# 1389               Microsoft  Office 365 Multi-Tenant & Supporting Services
# 1402               Microsoft  Office 365 Multi-Tenant & Supporting Services
# 1404               Microsoft                         Azure Commercial Cloud
# 1421               Microsoft  Office 365 Multi-Tenant & Supporting Services
#
#         Type  Leveraged A T O  Authorization Date  \
# 0        JAB              Yes                 NaN
# 12       JAB              Yes                 NaN
# 18       JAB              Yes                 NaN
# 31    Agency              Yes                 NaN
# 36       JAB              Yes                 NaN
# ...      ...              ...                 ...
# 1384  Agency              Yes                 NaN
# 1389  Agency              Yes                 NaN
# 1402  Agency              Yes                 NaN
# 1404     JAB              Yes                 NaN
# 1421  Agency              Yes                 NaN
#
#                                             Agency  \
# 0          Department of Health and Human Services
# 12                           Department of Justice
# 18                      Department of the Interior
# 31         Department of Health and Human Services
# 36         Department of Health and Human Services
# ...                                            ...
# 1384        United States House of Representatives
# 1389  United States International Trade Commission
# 1402                        Department of Commerce
# 1404                        Department of Commerce
# 1421    United States Trade and Development Agency
#
#                                               Subagency  Independent Assessor
# 0                Administration for Children & Families                   NaN
# 12    Bureau of Alcohol, Tobacco, Firearms and Explo...                   NaN
# 18                             Bureau of Indian Affairs                   NaN
# 31           Centers for Disease Control and Prevention                   NaN
# 36           Centers for Disease Control and Prevention                   NaN
# ...                                                 ...                   ...
# 1384                                                NaN                   NaN
# 1389                                                NaN                   NaN
# 1402          United States Patent and Trademark Office                   NaN
# 1404          United States Patent and Trademark Office                   NaN
# 1421                                                NaN                   NaN
#
# [164 rows x 8 columns]

# %%
fedramp_df[fedramp_df[' Cloud Service Provider']=='Amazon']
# Out:
#       Cloud Service Provider  Cloud Service Offering  Type  Leveraged A T O  \
# 26                    Amazon            AWS GovCloud   JAB              Yes
# 30                    Amazon        AWS US East/West   JAB              Yes
# 46                    Amazon            AWS GovCloud   JAB              Yes
# 49                    Amazon        AWS US East/West   JAB              Yes
# 61                    Amazon        AWS US East/West   JAB              Yes
# ...                      ...                     ...   ...              ...
# 1357                  Amazon            AWS GovCloud   JAB              Yes
# 1358                  Amazon            AWS GovCloud   JAB              Yes
# 1401                  Amazon        AWS US East/West   JAB              Yes
# 1413                  Amazon        AWS US East/West   JAB              Yes
# 1423                  Amazon            AWS GovCloud   JAB              Yes
#
#       Authorization Date                                            Agency  \
# 26                   NaN                        Department of the Treasury
# 30                   NaN           Department of Health and Human Services
# 46                   NaN           Department of Health and Human Services
# 49                   NaN           Department of Health and Human Services
# 61                   NaN              Consumer Financial Protection Bureau
# ...                  ...                                               ...
# 1357                 NaN                            Department of Commerce
# 1358                 NaN                            Department of Commerce
# 1401                 NaN                            Department of Commerce
# 1413                 NaN  United States Securities and Exchange Commission
# 1423                 NaN          Universal Service Administrative Company
#
#                                        Subagency  Independent Assessor
# 26                  Bureau of the Fiscal Service                   NaN
# 30    Centers for Disease Control and Prevention                   NaN
# 46      Centers for Medicare & Medicaid Services                   NaN
# 49      Centers for Medicare & Medicaid Services                   NaN
# 61                                           NaN                   NaN
# ...                                          ...                   ...
# 1357                 United States Census Bureau                   NaN
# 1358                 United States Census Bureau                   NaN
# 1401   United States Patent and Trademark Office                   NaN
# 1413                                         NaN                   NaN
# 1423                                         NaN                   NaN
#
# [122 rows x 8 columns]

# %%
fedramp_df[fedramp_df[' Cloud Service Provider']=='Google']
# Out:
#       Cloud Service Provider  \
# 232                   Google
# 240                   Google
# 241                   Google
# 405                   Google
# 676                   Google
# 1016                  Google
# 1024                  Google
# 1025                  Google
# 1067                  Google
# 1071                  Google
# 1085                  Google
# 1106                  Google
# 1142                  Google
# 1340                  Google
# 1405                  Google
#
#                                  Cloud Service Offering    Type  \
# 232   Google Services (Google Cloud Platform Product...     JAB
# 240                                      Google G Suite  Agency
# 241                                      Google G Suite  Agency
# 405                                      Google G Suite  Agency
# 676                                      Google G Suite  Agency
# 1016  Google Services (Google Cloud Platform Product...     JAB
# 1024                                     Google G Suite  Agency
# 1025                                     Google G Suite  Agency
# 1067                                     Google G Suite  Agency
# 1071                                     Google G Suite  Agency
# 1085                                     Google G Suite  Agency
# 1106                                     Google G Suite  Agency
# 1142                                     Google G Suite  Agency
# 1340                                     Google G Suite  Agency
# 1405  Google Services (Google Cloud Platform Product...     JAB
#
#       Leveraged A T O  Authorization Date  \
# 232               Yes                 NaN
# 240               Yes                 NaN
# 241               Yes                 NaN
# 405               Yes                 NaN
# 676               Yes                 NaN
# 1016              Yes                 NaN
# 1024               No          08/24/2020
# 1025              Yes                 NaN
# 1067              Yes                 NaN
# 1071              Yes                 NaN
# 1085              Yes                 NaN
# 1106              Yes                 NaN
# 1142              Yes                 NaN
# 1340              Yes                 NaN
# 1405              Yes                 NaN
#
#                                                  Agency  \
# 232                              Department of Commerce
# 240                              Department of Commerce
# 241                              Department of Commerce
# 405                                Department of Energy
# 676                          Department of the Interior
# 1016                    General Services Administration
# 1024                    General Services Administration
# 1025                    General Services Administration
# 1067                                Library of Congress
# 1071                               Department of Energy
# 1085       National Archives and Records Administration
# 1106                             Department of Commerce
# 1142                             Department of Commerce
# 1340  United States Agency for International Develop...
# 1405                             Department of Commerce
#
#                                             Subagency    Independent Assessor
# 232         United States Patent and Trademark Office                     NaN
# 240    National Institute of Standards and Technology                     NaN
# 241   National Oceanic and Atmospheric Administration                     NaN
# 405                    Los Alamos National Laboratory                     NaN
# 676                                               NaN                     NaN
# 1016                                              NaN                     NaN
# 1024                                              NaN  Coalfire Systems, Inc.
# 1025                                              NaN                     NaN
# 1067                                              NaN                     NaN
# 1071                   Los Alamos National Laboratory                     NaN
# 1085                                              NaN                     NaN
# 1106   National Institute of Standards and Technology                     NaN
# 1142  National Oceanic and Atmospheric Administration                     NaN
# 1340                                              NaN                     NaN
# 1405        United States Patent and Trademark Office                     NaN
