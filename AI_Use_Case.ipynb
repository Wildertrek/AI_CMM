# %% [markdown]
# __AI Use Case:__
# Name
#
# - __Version:__ 1.0
# - __Submission Date:__
# - __Publication Date:__
#
# __Please provide answers to the following questions in paragraph form. If you do not have an answer to any of the questions, you can skip the section and move on to the next question.__
#
# __Headline.__
# - Short (~70 characters). Benefits oriented, non-technical. Focus on the solution to the problem.
#
# __Summary.__
# - Short summary of the project (200 words). Benefits oriented, non-technical. Focus on the solution to the problem.
#
# __Business Problem.__
# - Background summary of business problem.
#
# __Benefits of the Solution.__
# - What are the benefits of the solution?
#
# __Context of Implementation.__
# - What prompted you to decide on this project?
# - What factors went into your decision to move forward with this project?
#
# __Future Development Goals.__
# - What extensions or opportunities for future applications are there?
#
# __Approach.__
# - Is there anything you want to tell us about how you approached the problem?
#
# __AI/ML Techniques.__
# - What specific AI or ML techniques did you use?
#
# __Data Approach.__
# - What can you tell us about the data set you used? What were your data challenges?
#
# __Technical Solution.__
# - What technical solutions (tools/software) were used?
#
# __Obstacles.__
# - What obstacles/considerations did you face to move or not move into the next stage of the AI life cycle?
#
# __Risk Assessment.__
# - Did you conduct a risk assessment of the AI solution?
# - What are your concerns about it?
#
# __Responsible AI Management.__
# Describe the training programs, roles and responsibilities, and codes of conduct for the workforce working with the AI system output and process.
# Will the AI system use Sensitive Personally Identifiable Information (SPII) or Personally Identifiable Information (PII) for training or operation? If so, what is your process for protecting it?
# How often will the system be audited to ensure it is performing as expected? (daily, weekly, monthly, quarterly, yearly, audit process still in development, other)
#
# __Metrics.__
# - What metrics did you use to measure the success of the AI solution?
#
# __Decision Making.__
# - What issues did you consider as you determined to move forward with this?
#
# __Development.__
# - What should we know about your development process?
#
# __Training / Roles & Responsibilities / Code of Conduct.__
# - Is there anything we should know about training or ethical AI use conduct that is specific to this project?
# - How are you planning to audit the system to ensure ongoing performance?
#
# __Lessons Learned.__
# - Summarize the top lessons learned from any phase of the AI system’s life cycle.
# - Is there anything else practitioners should know about this use case?
#
# __Contact Information__
#
# - __Name:__
# - __Agency/sub-agency:__
# - __Role:__ Government Employee, Academica, Industry, Other
# - __AI Role (select one):__ IT professional, System Operator, System Manager, Output Consumer, Data professional, Legal, Governance, Vendor/Contractor, Other
# - __Office:__
# - __Email:__
# - __Approval required by:__
#
# __Meta Data (Select answers relevant to the AI project)__
# Benefits: Decrease Cycle Time, Increase Accuracy, Increase Outputs, Improve Customer Service, New Service / Capability, Increase Compliance, Other
# Procurement: Developed in-house, commercial off-the-shelf, Joint development with external partner, Custom built by non-federal government entity, Joint project with another federal agency, Other
# Development Phase:
# Operational Use: Exploring options and capabilities, Prototype or Proof of Concept, Pilot, Production
# Research Project: Concept, IRB Approval, Research & Testing, Published, Ongoing Revisions
# Development:
# AI/ML Techniques: Image Recognition, Pattern and Anomaly Detection, Conversational AI and Chatbots, Natural Language Processing or Generation, Autonomous Systems, Predictive Analytics and Decision making, Goal-Driven Systems, Recommendations and Personalization, Intelligent Automation
# AI Lifecycle Stage: Planning and design, Verification and validation, Data collection and processing, Deployment, Model building and interpretation, Operation and monitoring
# Environment: Agriculture, Environment, Social and welfare issues, Competition, Finance and insurance, Tax, Corporate governance, Health, Trade, Development, Industry and entrepreneurship, Transport, Digital economy, Innovation, Economy, Investment, Education, Public governance, Employment, Science and technology, Law Enforcement, Transportation Security, Critical Infrastructure, Human Resources, immigration, Defense and Intelligence, Acquisition and Procurement, Other
# Use of SPII or PII: Yes, No
# Agency:
# Subagency:
#
# __Possible graphics, attachments or additional resources__
